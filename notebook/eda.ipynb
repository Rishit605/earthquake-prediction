# %%
import os
import sys

import pandas as pd
import geopandas as gpd
import numpy as np

import torch
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import  ReduceLROnPlateau
from torch.cuda.amp import GradScaler, autocast

import seaborn as sns
import matplotlib.pyplot  as plt

# sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))
from earthquake_prediction.src.helpers.datapi import url, url_data_call
from earthquake_prediction.src.model.model import Early_Stopping, ModelCheckPoint, EarthquakeModel
from earthquake_prediction.src.preprocessing.data_preprocessing import *
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 16
#      13 import seaborn as sns
#      14 import matplotlib.pyplot  as plt
# ---> 16 sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(...))))
#      17 from earthquake_prediction.src.helpers.datapi import url, url_data_call
#      18 from earthquake_prediction.src.model.model import Early_Stopping, ModelCheckPoint, EarthquakeModel
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ntpath.py:540, in abspath(path)
#     538 """Return the absolute version of a path."""
#     539 try:
# --> 540     return normpath(_getfullpathname(path))
#     541 except (OSError, ValueError):
#     542     return _abspath_fallback(path)
#
# TypeError: _getfullpathname: path should be string, bytes or os.PathLike, not ellipsis

# %%
df = url_data_call(url)
df = data_preprocessing(df, ts=True)
df = imput_encode(df)
df = CyclicTimeTransform(df)
df
# Out:
#                           mag    dmin   rms  magType   longitude   latitude  \
# time
# 2023-12-31 23:18:09.731  4.20  6.2370  0.53        0  143.560200  -4.259000
# 2023-12-31 22:52:31.316  4.20  9.1640  0.68        0  141.420800  -2.688600
# 2023-12-31 22:48:19.016  4.40  3.4550  0.54        0 -178.332700 -17.506500
# 2023-12-31 22:13:49.174  4.20  0.4520  0.53        0  144.589200  13.952600
# 2023-12-31 21:42:27.330  2.56  0.1071  0.17        2  -66.816000  18.064167
# ...                       ...     ...   ...      ...         ...        ...
# 2023-05-01 00:49:00.850  3.09  0.5998  0.21        2  -66.786167  18.948833
# 2023-05-01 00:46:53.270  3.13  0.6209  0.26        2  -66.760833  18.970833
# 2023-05-01 00:16:20.641  5.10  0.6850  0.66       12 -177.433500 -29.802000
# 2023-05-01 00:13:39.447  4.10  2.7470  0.74        0   56.695500  27.667900
# 2023-05-01 00:09:19.473  4.50  5.2540  0.51        0  179.958800 -23.942700
#
#                          elevation  Hour sin  Hour cos   Day sin   Day cos  \
# time
# 2023-12-31 23:18:09.731    133.548 -0.258819  0.965926  0.433884 -0.900969
# 2023-12-31 22:52:31.316     10.000 -0.500000  0.866025  0.433884 -0.900969
# 2023-12-31 22:48:19.016    540.654 -0.500000  0.866025  0.433884 -0.900969
# 2023-12-31 22:13:49.174    193.928 -0.500000  0.866025  0.433884 -0.900969
# 2023-12-31 21:42:27.330     14.760 -0.707107  0.707107  0.433884 -0.900969
# ...                            ...       ...       ...       ...       ...
# 2023-05-01 00:49:00.850     14.100  0.000000  1.000000  0.781831  0.623490
# 2023-05-01 00:46:53.270      8.300  0.000000  1.000000  0.781831  0.623490
# 2023-05-01 00:16:20.641     28.056  0.000000  1.000000  0.781831  0.623490
# 2023-05-01 00:13:39.447     10.000  0.000000  1.000000  0.781831  0.623490
# 2023-05-01 00:09:19.473    503.199  0.000000  1.000000  0.781831  0.623490
#
#                             Month sin  Month cos  day_of_year  month
# time
# 2023-12-31 23:18:09.731 -2.449294e-16   1.000000          365     12
# 2023-12-31 22:52:31.316 -2.449294e-16   1.000000          365     12
# 2023-12-31 22:48:19.016 -2.449294e-16   1.000000          365     12
# 2023-12-31 22:13:49.174 -2.449294e-16   1.000000          365     12
# 2023-12-31 21:42:27.330 -2.449294e-16   1.000000          365     12
# ...                               ...        ...          ...    ...
# 2023-05-01 00:49:00.850  5.000000e-01  -0.866025          121      5
# 2023-05-01 00:46:53.270  5.000000e-01  -0.866025          121      5
# 2023-05-01 00:16:20.641  5.000000e-01  -0.866025          121      5
# 2023-05-01 00:13:39.447  5.000000e-01  -0.866025          121      5
# 2023-05-01 00:09:19.473  5.000000e-01  -0.866025          121      5
#
# [18144 rows x 15 columns]

# %%
# Defining the Window size and Target Predictions
window_size = 24
target_column = df.columns[:7]

# %%
# Defining the Input and Output Features
X1 = df
Y1 = df[target_column]

# %%
# Scaling the Dataset
scaled_X, scaler_X = scaler_dataset(X1)
scaled_Y, scaler_Y = scaler_dataset(Y1)

# %%
# Creting the Window Sequences
X, Y = SingleStepMultiVARS_SeperateSampler(scaled_X, scaled_Y, window_size, target_column)
X, Y = np.array(X), np.array(Y)

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_dataset(X, Y)

# %%
# Converting the dataset to Torch DataLoader format
BATCH_SIZE = 64

train_tensor = TensorDataset(torch.FloatTensor(X_train), torch.FloatTensor(y_train))
valid_tensor = TensorDataset(torch.FloatTensor(X_val), torch.FloatTensor(y_val))
test_tensor = TensorDataset(torch.FloatTensor(X_test), torch.FloatTensor(y_test))

train_dataloader = DataLoader(
    train_tensor, 
    batch_size=BATCH_SIZE, 
    shuffle=False
)

valid_dataloader = DataLoader(
    valid_tensor,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_dataloader = DataLoader(
    test_tensor,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %%
# Hyperparameters
input_size = X.shape[-1]
hidden_size = 128
num_layers = 4
dropout_prob = 0.45
output_size = len(target_column)
n_epochs = 20
learning_rate = 0.001

early_stopping = Early_Stopping(patience=20, verbose=True)
checkpoint = ModelCheckPoint(file_path=r'C:\Projs\COde\Meteo\MetP\src\model\new_best_lstm_model.pth', verbose=True)

# %%
model = EarthquakeModel(input_size, hidden_size, num_layers, output_size, dropout_prob).to("cuda")
criterion = nn.HuberLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 model = EarthquakeModel(input_size, hidden_size, num_layers, output_size, dropout_prob).to("cuda")
#       2 criterion = nn.HuberLoss()
#       3 optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-5)
#
# File c:\Users\Rishi\AppData\Local\pypoetry\Cache\virtualenvs\eq-L7llixk8-py3.11\Lib\site-packages\torch\nn\modules\module.py:1173, in Module.to(self, *args, **kwargs)
#    1170         else:
#    1171             raise
# -> 1173 return self._apply(convert)
#
# File c:\Users\Rishi\AppData\Local\pypoetry\Cache\virtualenvs\eq-L7llixk8-py3.11\Lib\site-packages\torch\nn\modules\module.py:779, in Module._apply(self, fn, recurse)
#     777 if recurse:
#     778     for module in self.children():
# --> 779         module._apply(fn)
#     781 def compute_should_use_set_data(tensor, tensor_applied):
#     782     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     783         # If the new tensor has compatible tensor type as the existing tensor,
#     784         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     789         # global flag to let the user control whether they want the future
#     790         # behavior of overwriting the existing tensor or not.
#
# File c:\Users\Rishi\AppData\Local\pypoetry\Cache\virtualenvs\eq-L7llixk8-py3.11\Lib\site-packages\torch\nn\modules\rnn.py:217, in RNNBase._apply(self, fn, recurse)
#     215 def _apply(self, fn, recurse=True):
#     216     self._flat_weight_refs = []
# --> 217     ret = super()._apply(fn, recurse)
#     219     # Resets _flat_weights
#     220     # Note: be v. careful before removing this, as 3rd party device types
#     221     # likely rely on this behavior to properly .to() modules like LSTM.
#     222     self._init_flat_weights()
#
# File c:\Users\Rishi\AppData\Local\pypoetry\Cache\virtualenvs\eq-L7llixk8-py3.11\Lib\site-packages\torch\nn\modules\module.py:804, in Module._apply(self, fn, recurse)
#     800 # Tensors stored in modules are graph leaves, and we don't want to
#     801 # track autograd history of `param_applied`, so we have to use
#     802 # `with torch.no_grad():`
#     803 with torch.no_grad():
# --> 804     param_applied = fn(param)
#     805 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     807 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File c:\Users\Rishi\AppData\Local\pypoetry\Cache\virtualenvs\eq-L7llixk8-py3.11\Lib\site-packages\torch\nn\modules\module.py:1159, in Module.to.<locals>.convert(t)
#    1152     if convert_to_format is not None and t.dim() in (4, 5):
#    1153         return t.to(
#    1154             device,
#    1155             dtype if t.is_floating_point() or t.is_complex() else None,
#    1156             non_blocking,
#    1157             memory_format=convert_to_format,
#    1158         )
# -> 1159     return t.to(
#    1160         device,
#    1161         dtype if t.is_floating_point() or t.is_complex() else None,
#    1162         non_blocking,
#    1163     )
#    1164 except NotImplementedError as e:
#    1165     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# File c:\Users\Rishi\AppData\Local\pypoetry\Cache\virtualenvs\eq-L7llixk8-py3.11\Lib\site-packages\torch\cuda\__init__.py:284, in _lazy_init()
#     279     raise RuntimeError(
#     280         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     281         "multiprocessing, you must use the 'spawn' start method"
#     282     )
#     283 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 284     raise AssertionError("Torch not compiled with CUDA enabled")
#     285 if _cudart is None:
#     286     raise AssertionError(
#     287         "libcudart functions unavailable. It looks like you have a broken build?"
#     288     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
scaler = GradScaler()
def train_model(model, train_loader, val_loader, criterion, optimizer, lscheduler, num_epochs, early_stopping, checkpoint):
    train_losses, val_losses = [], []
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        for inputs, targets in train_loader:
            inputs, targets = inputs.to("cuda"), targets.to("cuda")
            optimizer.zero_grad()
            
            with autocast():
                outputs = model(inputs)
                loss = criterion(outputs, targets)
            
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        train_losses.append(train_loss)
        
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs, targets = inputs.to("cuda"), targets.to("cuda")
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                val_loss += loss.item()
        
        val_loss /= len(val_loader)
        val_losses.append(val_loss)
        
        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")
        
        scheduler.step(val_loss)
        early_stopping(val_loss)
        checkpoint(model, val_loss)
        
        # if early_stopping.early_stop:
        #     print("Early stopping triggered")
        #     break
    
    return train_losses, val_losses

train_losses, val_losses = train_model(model, train_dataloader, valid_dataloader, criterion, optimizer, scheduler, n_epochs, early_stopping, checkpoint)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 49
#      43         # if early_stopping.early_stop:
#      44         #     print("Early stopping triggered")
#      45         #     break
#      47     return train_losses, val_losses
# ---> 49 train_losses, val_losses = train_model(model, train_dataloader, valid_dataloader, criterion, optimizer, scheduler, n_epochs, early_stopping, checkpoint)
#
# NameError: name 'model' is not defined

# %%
## Validation Step for the Enhanced model.
def test_step():
    # Evaluate on test set
    model.load_state_dict(torch.load(model))
    model.eval()
    test_loss = 0
    predictions = []
    actuals = []

    with torch.no_grad():
        for inputs, targets in test_dataloader:
            inputs, targets = inputs.to("cuda"), targets.to("cuda")
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            test_loss += loss.item()
            predictions.extend(outputs.cpu().numpy())
            actuals.extend(targets.cpu().numpy())

    test_loss /= len(test_dataloader)
    print(f"Test Loss: {test_loss:.4f}")

    # Denormalize predictions and actuals
    predictions = scaler_Y.inverse_transform(np.array(predictions))
    actuals = scaler_Y.inverse_transform(np.array(actuals))

    # Calculate RMSE for each target variable
    for i, col in enumerate(target_column):
        rmse = np.sqrt(np.mean((predictions[:, i] - actuals[:, i])**2))
        print(f"RMSE for {col}: {rmse:.4f}")

# %% [markdown]
# ---
#
# # Data Manipulation 2

# %%
import os
import sys
sys.path.append(os.path.abspath('..'))

import pandas as pd
import numpy as np

from src.helpers.datapi import datas, url_data_call
from src.model.model import Early_Stopping, ModelCheckPoint, EarthquakeModel
from src.preprocessing.data_preprocessing import *

import datetime
from datetime import timedelta


def data_prep() -> pd.DataFrame:
    df = pd.DataFrame()

    for key, values in datas.items():
        # print(f"{key} with value: {values}")
        pseudo_df = url_data_call(datas[key])

        df = pd.concat([df, pseudo_df])

    return df


def prep_D(data_Frame: pd.DataFrame):
    df = data_preprocessing(data_Frame, ts=True)

    df = imput_encode(df)

    df2_ffill = df.copy()
    df2_ffill['dmin'] = df2_ffill['dmin'].ffill()    
    df2_ffill = CyclicTimeTransform(df2_ffill)

    X1, Y1, target_columns = var_and_tar(df2_ffill)
    scaled_X, scaler_X = scaler_dataset(X1)
    scaled_Y, scaler_Y = scaler_dataset(Y1)

    return scaled_X, scaled_Y, scaler_X, scaler_Y
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 8
#       5 import pandas as pd
#       6 import numpy as np
# ----> 8 from src.helpers.datapi import datas, url_data_call
#       9 from src.model.model import Early_Stopping, ModelCheckPoint, EarthquakeModel
#      10 from src.preprocessing.data_preprocessing import *
#
# ImportError: cannot import name 'datas' from 'src.helpers.datapi' (c:\Projs\COde\Earthquake\eq_prediction\src\helpers\datapi.py)

# %%
dicg = df.isna().any().to_dict()
dicg
# Out:
# {'mag': False,
#  'dmin': False,
#  'rms': False,
#  'magType': False,
#  'longitude': False,
#  'latitude': False,
#  'elevation': False}

# %%
df = data_prep()
# scaled_X, scaled_Y, scaler_X, scaler_Y = prep_D(data_Frame=df)

# %% [markdown]
# #### Data Manipulation.. Nuff Said

# %%
# Testing the Data and its missing value randomness and bias.
'''
from statsmodels.imputation.mice import test_mcar

# Perform Little's MCAR test
statistic, p_value = test_mcar(df)

print(f"Chi-square statistic: {statistic}")
print(f"P-value: {p_value}")
'''
# Out:
# '\nfrom statsmodels.imputation.mice import test_mcar\n\n# Perform Little\'s MCAR test\nstatistic, p_value = test_mcar(df)\n\nprint(f"Chi-square statistic: {statistic}")\nprint(f"P-value: {p_value}")\n'

# %%
df = data_preprocessing(df, ts=True)
df = imput_encode(df)
df
# Out:
#                           mag    dmin   rms  magType   longitude   latitude  \
# time
# 2022-12-31 23:54:48.008  3.60  1.0600  0.51        4 -166.619200  52.694100
# 2022-12-31 23:04:12.381  4.90  1.0960  0.75       13  -69.659000 -16.501300
# 2022-12-31 22:44:54.316  4.10  3.7780  0.46        0 -179.737700 -17.770500
# 2022-12-31 21:14:58.931  3.00  3.7780  0.67        4 -151.154700  62.404900
# 2022-12-31 21:00:24.164  2.60  0.6190  0.42        4 -176.029300  51.290000
# ...                       ...     ...   ...      ...         ...        ...
# 2023-05-01 00:49:00.850  3.09  0.5998  0.21        2  -66.786167  18.948833
# 2023-05-01 00:46:53.270  3.13  0.6209  0.26        2  -66.760833  18.970833
# 2023-05-01 00:16:20.641  5.10  0.6850  0.66       13 -177.433500 -29.802000
# 2023-05-01 00:13:39.447  4.10  2.7470  0.74        0   56.695500  27.667900
# 2023-05-01 00:09:19.473  4.50  5.2540  0.51        0  179.958800 -23.942700
#
#                          elevation
# time
# 2022-12-31 23:54:48.008     35.000
# 2022-12-31 23:04:12.381    190.386
# 2022-12-31 22:44:54.316    613.983
# 2022-12-31 21:14:58.931      6.600
# 2022-12-31 21:00:24.164     10.000
# ...                            ...
# 2023-05-01 00:49:00.850     14.100
# 2023-05-01 00:46:53.270      8.300
# 2023-05-01 00:16:20.641     28.056
# 2023-05-01 00:13:39.447     10.000
# 2023-05-01 00:09:19.473    503.199
#
# [44568 rows x 7 columns]

# %%
np.ptp(df['magType'], axis=0)
# Out:
# 13

# %%
df2 = df.copy()
df2.reset_index(inplace=True)

df2['time_since_last_event'] = df2['time'].diff().dt.total_seconds()
df2['time_since_last_event'] = df2['time_since_last_event'].fillna(0)
df2
# Out:
#                          time   mag    dmin   rms  magType   longitude  \
# 0     2022-12-31 23:54:48.008  3.60  1.0600  0.51        4 -166.619200
# 1     2022-12-31 23:04:12.381  4.90  1.0960  0.75       13  -69.659000
# 2     2022-12-31 22:44:54.316  4.10  3.7780  0.46        0 -179.737700
# 3     2022-12-31 21:14:58.931  3.00     NaN  0.67        4 -151.154700
# 4     2022-12-31 21:00:24.164  2.60  0.6190  0.42        4 -176.029300
# ...                       ...   ...     ...   ...      ...         ...
# 44563 2023-05-01 00:49:00.850  3.09  0.5998  0.21        2  -66.786167
# 44564 2023-05-01 00:46:53.270  3.13  0.6209  0.26        2  -66.760833
# 44565 2023-05-01 00:16:20.641  5.10  0.6850  0.66       13 -177.433500
# 44566 2023-05-01 00:13:39.447  4.10  2.7470  0.74        0   56.695500
# 44567 2023-05-01 00:09:19.473  4.50  5.2540  0.51        0  179.958800
#
#         latitude  elevation  time_since_last_event
# 0      52.694100     35.000                  0.000
# 1     -16.501300    190.386              -3035.627
# 2     -17.770500    613.983              -1158.065
# 3      62.404900      6.600              -5395.385
# 4      51.290000     10.000               -874.767
# ...          ...        ...                    ...
# 44563  18.948833     14.100               -191.400
# 44564  18.970833      8.300               -127.580
# 44565 -29.802000     28.056              -1832.629
# 44566  27.667900     10.000               -161.194
# 44567 -23.942700    503.199               -259.974
#
# [44568 rows x 9 columns]

# %%
# Create spatial-temporal grid
df2['time_bin'] = pd.to_datetime(df2['time']).dt.to_period('D')  # Daily bins
df2['lat_bin'] = pd.cut(df2['latitude'], bins=50)  # Adjust bin number as needed
df2['lon_bin'] = pd.cut(df2['longitude'], bins=50)

# %%
df2.mag.describe()
# Out:
# count    44568.000000
# mean         3.874214
# std          0.857750
# min          2.500000
# 25%          3.000000
# 50%          4.200000
# 75%          4.500000
# max          7.800000
# Name: mag, dtype: float64

# %%
# Aggregate features
agg_df = df2.groupby(['time_bin', 'lat_bin', 'lon_bin']).agg({
    'mag': ['count', 'max', 'mean'],
    'time': lambda x: (x.max() - x.min()).total_seconds()  # Time span
}).reset_index()
# Out:
# C:\Users\Rishi\AppData\Local\Temp\ipykernel_19464\860044554.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df = df2.groupby(['time_bin', 'lat_bin', 'lon_bin']).agg({

# %%
agg_df.columns = ['time_bin', 'lat_bin', 'lon_bin', 'eq_count', 'max_magnitude', 'avg_magnitude', 'time_span']

# %%
agg_df
# Out:
#            time_bin           lat_bin               lon_bin  eq_count  \
# 0        2022-05-01  (-66.002, -62.8]  (-180.359, -172.799]         1
# 1        2022-05-01  (-66.002, -62.8]  (-172.799, -165.599]         0
# 2        2022-05-01  (-66.002, -62.8]  (-165.599, -158.399]         0
# 3        2022-05-01  (-66.002, -62.8]  (-158.399, -151.199]         0
# 4        2022-05-01  (-66.002, -62.8]  (-151.199, -143.999]         0
# ...             ...               ...                   ...       ...
# 1524995  2023-12-31  (83.598, 86.648]        (144.0, 151.2]         0
# 1524996  2023-12-31  (83.598, 86.648]        (151.2, 158.4]         0
# 1524997  2023-12-31  (83.598, 86.648]      (158.4, 165.599]         0
# 1524998  2023-12-31  (83.598, 86.648]    (165.599, 172.799]         0
# 1524999  2023-12-31  (83.598, 86.648]    (172.799, 179.999]         0
#
#          max_magnitude  avg_magnitude  time_span
# 0                  4.7            4.7        0.0
# 1                  NaN            NaN        NaN
# 2                  NaN            NaN        NaN
# 3                  NaN            NaN        NaN
# 4                  NaN            NaN        NaN
# ...                ...            ...        ...
# 1524995            NaN            NaN        NaN
# 1524996            NaN            NaN        NaN
# 1524997            NaN            NaN        NaN
# 1524998            NaN            NaN        NaN
# 1524999            NaN            NaN        NaN
#
# [1525000 rows x 7 columns]

# %%
# Create target variables
agg_df['eq_occurred'] = (agg_df['eq_count'] > 0).astype(int)
agg_df
# Out:
#            time_bin           lat_bin               lon_bin  eq_count  \
# 0        2022-05-01  (-66.002, -62.8]  (-180.359, -172.799]         1
# 1        2022-05-01  (-66.002, -62.8]  (-172.799, -165.599]         0
# 2        2022-05-01  (-66.002, -62.8]  (-165.599, -158.399]         0
# 3        2022-05-01  (-66.002, -62.8]  (-158.399, -151.199]         0
# 4        2022-05-01  (-66.002, -62.8]  (-151.199, -143.999]         0
# ...             ...               ...                   ...       ...
# 1524995  2023-12-31  (83.598, 86.648]        (144.0, 151.2]         0
# 1524996  2023-12-31  (83.598, 86.648]        (151.2, 158.4]         0
# 1524997  2023-12-31  (83.598, 86.648]      (158.4, 165.599]         0
# 1524998  2023-12-31  (83.598, 86.648]    (165.599, 172.799]         0
# 1524999  2023-12-31  (83.598, 86.648]    (172.799, 179.999]         0
#
#          max_magnitude  avg_magnitude  time_span  eq_occurred
# 0                  4.7            4.7        0.0            1
# 1                  NaN            NaN        NaN            0
# 2                  NaN            NaN        NaN            0
# 3                  NaN            NaN        NaN            0
# 4                  NaN            NaN        NaN            0
# ...                ...            ...        ...          ...
# 1524995            NaN            NaN        NaN            0
# 1524996            NaN            NaN        NaN            0
# 1524997            NaN            NaN        NaN            0
# 1524998            NaN            NaN        NaN            0
# 1524999            NaN            NaN        NaN            0
#
# [1525000 rows x 8 columns]

# %%
# df.set_index('timestamp', inplace=True)
scaled_X2 = scaled_X.copy()
scaled_X2.reset_index(inplace=True)
scaled_X2['time']

# Time since last event
scaled_X2['time_since_last_event'] = scaled_X2['time'].diff().dt.total_seconds()

# %%
# Create spatial-temporal grid
scaled_X2['time_bin'] = pd.to_datetime(scaled_X2['timestamp']).dt.to_period('D')  # Daily bins
scaled_X2['lat_bin'] = pd.cut(scaled_X2['latitude'], bins=50)  # Adjust bin number as needed
scaled_X2['lon_bin'] = pd.cut(scaled_X2['longitude'], bins=50)

# %%
scaled_X2.describe()
# Out:
#                                 time           mag          dmin  \
# count                          44568  44568.000000  44568.000000
# mean   2023-03-06 07:22:12.514709760      0.259286      0.050399
# min       2022-05-01 00:02:55.593000      0.000000      0.000000
# 25%    2022-10-01 19:14:15.496750080      0.094340      0.009312
# 50%    2023-03-02 22:35:14.872999936      0.320755      0.026928
# 75%       2023-08-06 19:52:42.012000      0.377358      0.058793
# max       2023-12-31 23:18:09.731000      1.000000      1.000000
# std                              NaN      0.161840      0.078753
#
#                 rms       magType     longitude      latitude     elevation  \
# count  44568.000000  44568.000000  44568.000000  44568.000000  44568.000000
# mean       0.300489      0.171227      0.432719      0.554820      0.100025
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.196721      0.000000      0.071912      0.394231      0.020059
# 50%        0.306011      0.000000      0.314093      0.558105      0.033198
# 75%        0.393443      0.307692      0.850201      0.736930      0.097876
# max        1.000000      1.000000      1.000000      1.000000      1.000000
# std        0.144171      0.252986      0.357661      0.199926      0.166572
#
#            Hour sin      Hour cos       Day sin       Day cos     Month sin  \
# count  44568.000000  44568.000000  44568.000000  4.456800e+04  44568.000000
# mean       0.503513      0.506551      0.536587  4.675826e-01      0.421292
# min        0.000000      0.000000      0.000000  0.000000e+00      0.000000
# 25%        0.146447      0.146447      0.099031  6.661338e-16      0.066987
# 50%        0.500000      0.500000      0.500000  3.568959e-01      0.500000
# 75%        0.853553      0.853553      0.900969  8.019377e-01      0.750000
# max        1.000000      1.000000      1.000000  1.000000e+00      1.000000
# std        0.353436      0.353601      0.365372  3.671948e-01      0.328462
#
#           Month cos   day_of_year         month  time_since_last_event
# count  44568.000000  44568.000000  44568.000000           4.456700e+04
# mean       0.492095      0.569425      0.578534           2.326581e+02
# min        0.000000      0.000000      0.000000          -1.477055e+04
# 25%        0.066987      0.373626      0.363636          -1.613947e+03
# 50%        0.500000      0.590659      0.636364          -7.666830e+02
# 75%        0.933013      0.802198      0.818182          -3.023810e+02
# max        1.000000      1.000000      1.000000           3.153572e+07
# std        0.368593      0.273326      0.295512           2.112490e+05

# %%
scaled_X2 = scaled_X2.fillna(0)
scaled_X2
# scaled_X2.isna().sum()
# Out:
#                          time       mag      dmin       rms   magType  \
# 0     2022-12-31 23:54:48.008  0.207547  0.020031  0.278689  0.307692
# 1     2022-12-31 23:04:12.381  0.452830  0.020711  0.409836  1.000000
# 2     2022-12-31 22:44:54.316  0.301887  0.071392  0.251366  0.000000
# 3     2022-12-31 21:14:58.931  0.094340  0.071392  0.366120  0.307692
# 4     2022-12-31 21:00:24.164  0.018868  0.011697  0.229508  0.307692
# ...                       ...       ...       ...       ...       ...
# 44563 2023-05-01 00:49:00.850  0.111321  0.011334  0.114754  0.153846
# 44564 2023-05-01 00:46:53.270  0.118868  0.011733  0.142076  0.153846
# 44565 2023-05-01 00:16:20.641  0.490566  0.012944  0.360656  1.000000
# 44566 2023-05-01 00:13:39.447  0.301887  0.051910  0.404372  0.000000
# 44567 2023-05-01 00:09:19.473  0.377358  0.099284  0.278689  0.000000
#
#        longitude  latitude  elevation  Hour sin  Hour cos   Day sin  \
# 0       0.037165  0.777350   0.056557  0.370590  0.982963  0.722521
# 1       0.306501  0.323602   0.283405  0.370590  0.982963  0.722521
# 2       0.000725  0.315279   0.901814  0.250000  0.933013  0.722521
# 3       0.080123  0.841028   0.015095  0.146447  0.853553  0.722521
# 4       0.011026  0.768142   0.020059  0.146447  0.853553  0.722521
# ...          ...       ...        ...       ...       ...       ...
# 44563   0.314481  0.556065   0.026045  0.500000  1.000000  0.900969
# 44564   0.314551  0.556210   0.017577  0.500000  1.000000  0.900969
# 44565   0.007126  0.236382   0.046419  0.500000  1.000000  0.900969
# 44566   0.657487  0.613241   0.020059  0.500000  1.000000  0.900969
# 44567   0.999887  0.274805   0.740081  0.500000  1.000000  0.900969
#
#             Day cos  Month sin  Month cos  day_of_year     month  \
# 0      7.216450e-16       0.50   1.000000      1.00000  1.000000
# 1      7.216450e-16       0.50   1.000000      1.00000  1.000000
# 2      7.216450e-16       0.50   1.000000      1.00000  1.000000
# 3      7.216450e-16       0.50   1.000000      1.00000  1.000000
# 4      7.216450e-16       0.50   1.000000      1.00000  1.000000
# ...             ...        ...        ...          ...       ...
# 44563  8.019377e-01       0.75   0.066987      0.32967  0.363636
# 44564  8.019377e-01       0.75   0.066987      0.32967  0.363636
# 44565  8.019377e-01       0.75   0.066987      0.32967  0.363636
# 44566  8.019377e-01       0.75   0.066987      0.32967  0.363636
# 44567  8.019377e-01       0.75   0.066987      0.32967  0.363636
#
#        time_since_last_event
# 0                      0.000
# 1                  -3035.627
# 2                  -1158.065
# 3                  -5395.385
# 4                   -874.767
# ...                      ...
# 44563               -191.400
# 44564               -127.580
# 44565              -1832.629
# 44566               -161.194
# 44567               -259.974
#
# [44568 rows x 17 columns]

# %%
# Event counts in different windows
for window in [1, 7, 30]:
    scaled_X2[f'events_last_{window}'] = scaled_X2['time'].rolling(window).count()

# %%
scaled_X2['events_last_7d'] = scaled_X2['time'].rolling(window=7).count()

# %%
# Resampled daily features
daily_df = scaled_X2.resample('D', on='time').agg({
    'mag': ['count', 'max', 'mean'],
    'time_since_last_event': 'mean'
})
daily_df.columns = ['_'.join(col).strip() for col in daily_df.columns.values]

# %%
daily_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 daily_df
#
# NameError: name 'daily_df' is not defined

# %%
# Merge daily features back to original DataFrame
new_scaled_X2 = pd.merge_asof(scaled_X2, daily_df, left_on='time', right_index=True)

# Add cumulative features
new_scaled_X2['cumulative_events'] = range(1, len(new_scaled_X2) + 1)
new_scaled_X2s['cumulative_magnitude'] = new_scaled_X2['magnitude'].cumsum()
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Merge daily features back to original DataFrame
# ----> 2 new_scaled_X2 = pd.merge_asof(scaled_X2, daily_df)
#       4 # Add cumulative features
#       5 new_scaled_X2['cumulative_events'] = range(1, len(new_scaled_X2) + 1)
#
# File c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\pandas\core\reshape\merge.py:691, in merge_asof(left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, tolerance, allow_exact_matches, direction)
#     440 def merge_asof(
#     441     left: DataFrame | Series,
#     442     right: DataFrame | Series,
#    (...)
#     454     direction: str = "backward",
#     455 ) -> DataFrame:
#     456     """
#     457     Perform a merge by key distance.
#     458
#    (...)
#     689     4 2016-05-25 13:30:00.048   AAPL   98.00       100     NaN     NaN
#     690     """
# --> 691     op = _AsOfMerge(
#     692         left,
#     693         right,
#     694         on=on,
#     695         left_on=left_on,
#     696         right_on=right_on,
#     697         left_index=left_index,
#     698         right_index=right_index,
#     699         by=by,
#     700         left_by=left_by,
#     701         right_by=right_by,
#     702         suffixes=suffixes,
#     703         how="asof",
#     704         tolerance=tolerance,
#     705         allow_exact_matches=allow_exact_matches,
#     706         direction=direction,
#     707     )
#     708     return op.get_result()
#
# File c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\pandas\core\reshape\merge.py:1999, in _AsOfMerge.__init__(self, left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, how, tolerance, allow_exact_matches, direction)
#    1993     msg = (
#    1994         "allow_exact_matches must be boolean, "
#    1995         f"passed {self.allow_exact_matches}"
#    1996     )
#    1997     raise MergeError(msg)
# -> 1999 _OrderedMerge.__init__(
#    2000     self,
#    2001     left,
#    2002     right,
#    2003     on=on,
#    2004     left_on=left_on,
#    2005     right_on=right_on,
#    2006     left_index=left_index,
#    2007     right_index=right_index,
#    2008     how=how,
#    2009     suffixes=suffixes,
#    2010     fill_method=None,
#    2011 )
#
# File c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\pandas\core\reshape\merge.py:1911, in _OrderedMerge.__init__(self, left, right, on, left_on, right_on, left_index, right_index, suffixes, fill_method, how)
#    1897 def __init__(
#    1898     self,
#    1899     left: DataFrame | Series,
#    (...)
#    1908     how: JoinHow | Literal["asof"] = "outer",
#    1909 ) -> None:
#    1910     self.fill_method = fill_method
# -> 1911     _MergeOperation.__init__(
#    1912         self,
#    1913         left,
#    1914         right,
#    1915         on=on,
#    1916         left_on=left_on,
#    1917         left_index=left_index,
#    1918         right_index=right_index,
#    1919         right_on=right_on,
#    1920         how=how,
#    1921         suffixes=suffixes,
#    1922         sort=True,  # factorize sorts
#    1923     )
#
# File c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\pandas\core\reshape\merge.py:786, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     779     msg = (
#     780         "Not allowed to merge between different levels. "
#     781         f"({_left.columns.nlevels} levels on the left, "
#     782         f"{_right.columns.nlevels} on the right)"
#     783     )
#     784     raise MergeError(msg)
# --> 786 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     788 (
#     789     self.left_join_keys,
#     790     self.right_join_keys,
#    (...)
#     793     right_drop,
#     794 ) = self._get_merge_keys()
#     796 if left_drop:
#
# File c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\pandas\core\reshape\merge.py:2014, in _AsOfMerge._validate_left_right_on(self, left_on, right_on)
#    2013 def _validate_left_right_on(self, left_on, right_on):
# -> 2014     left_on, right_on = super()._validate_left_right_on(left_on, right_on)
#    2016     # we only allow on to be a single item for on
#    2017     if len(left_on) != 1 and not self.left_index:
#
# File c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\pandas\core\reshape\merge.py:1572, in _MergeOperation._validate_left_right_on(self, left_on, right_on)
#    1570 common_cols = left_cols.intersection(right_cols)
#    1571 if len(common_cols) == 0:
# -> 1572     raise MergeError(
#    1573         "No common columns to perform merge on. "
#    1574         f"Merge options: left_on={left_on}, "
#    1575         f"right_on={right_on}, "
#    1576         f"left_index={self.left_index}, "
#    1577         f"right_index={self.right_index}"
#    1578     )
#    1579 if (
#    1580     not left_cols.join(common_cols, how="inner").is_unique
#    1581     or not right_cols.join(common_cols, how="inner").is_unique
#    1582 ):
#    1583     raise MergeError(f"Data columns not unique: {repr(common_cols)}")
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
daily_df
# Out:
#             mag_count   mag_max  mag_mean  time_since_last_event_mean
# time
# 2022-05-01         64  0.566038  0.259611                -1422.193328
# 2022-05-02         64  0.584906  0.222406                -1277.756125
# 2022-05-03         64  0.471698  0.221728                -1415.068313
# 2022-05-04         65  0.584906  0.265544                -1267.787062
# 2022-05-05         74  0.660377  0.277384                -1164.871432
# ...               ...       ...       ...                         ...
# 2023-12-27         76  0.622642  0.216509                -1048.242474
# 2023-12-28         74  0.754717  0.281515                -1162.970689
# 2023-12-29         77  0.603774  0.263293                -1119.976351
# 2023-12-30         86  0.716981  0.264063                -1007.776872
# 2023-12-31         73  0.528302  0.241897               430784.745178
#
# [610 rows x 4 columns]

# %%
import os
import sys

import pandas as pd
import numpy as np

sys.path.append(os.path.abspath('..'))

from src.helpers.datapi import datas, url_data_call
from src.model.model import Early_Stopping, ModelCheckPoint, EarthquakeModel
from src.preprocessing.data_preprocessing import *

def raw_data_prep() -> pd.DataFrame:
    """
    Calls and defines the data and returns a Pandas DataFrame with basic preprocssing.
    """
    df = pd.DataFrame()

    for key, values in datas.items():
        # print(f"{key} with value: {values}")
        pseudo_df = url_data_call(datas[key])

        df = pd.concat([df, pseudo_df])

    df = data_preprocessing(df, ts=True) ## This function performs basic proecprocessing with an option of Timeseries or not.
    df = imput_encode(df) ## This function encodes and imputs the input data and fills the empty values.

    return df

def prep_D(data_Frame: pd.DataFrame):
    """
    Takes in the raw dataframe and returns a curated and scaled dataframe
    """
    df2_ffill = df.copy()
    df2_ffill = CyclicTimeTransform(df2_ffill)

    X1, Y1, target_columns = var_and_tar(df2_ffill)
    scaled_X, scaler_X = scaler_dataset(X1)
    scaled_Y, scaler_Y = scaler_dataset(Y1)

    return scaled_X, scaled_Y, scaler_X, scaler_Y

def event_counts_for_diff_window(dataFrame: pd.DataFrame) -> pd.DataFrame:
    new_df = dataFrame.copy()

    new_df.reset_index(inplace=True)
    new_df.sort_values('time', inplace=True)

    new_df['time_since_last_event'] = new_df['time'].diff().dt.total_seconds()
    # new_df['time_since_last_event'] = new_df['time_since_last_event'].fillna(0)
    
    # Event counts in different windows
    for window in [1, 7, 30]:
        new_df[f'events_last_{window}'] = new_df['time'].rolling(window).count()

    new_df = new_df.fillna(0)
    daily_df = new_df.resample('D', on='time').agg({
    'mag': ['count', 'max', 'mean'],
    'time_since_last_event': 'mean'
    })

    daily_df.columns = ['_'.join(col).strip() for col in daily_df.columns.values]
    daily_df = daily_df.reset_index()

    # # Merge daily features back to original DataFrame
    new_df = pd.merge_asof(df, daily_df, left_on='time', right_on='time', 
                   tolerance=pd.Timedelta('1D'), direction='backward')
    return new_df


df  = raw_data_prep() # Getting the Data
df2 = df.copy()

# agg_df = event_counts_for_diff_window(dataFrame=df2)

event_counts_for_diff_window(dataFrame=df2)
# Out:
#                          time   mag     dmin   rms  magType  longitude  \
# 0     2022-05-01 00:02:55.593  4.40  20.9710  0.64        0    27.6375
# 1     2022-05-01 01:22:46.818  4.70   2.5540  0.77        0   142.3848
# 2     2022-05-01 01:33:35.201  4.20   1.3460  1.06        0    24.1134
# 3     2022-05-01 01:52:26.244  4.50   1.6090  0.83        0   126.4725
# 4     2022-05-01 02:10:52.717  4.30   2.4160  0.65        0   127.9058
# ...                       ...   ...      ...   ...      ...        ...
# 44563 2023-12-31 21:42:27.330  2.56   0.1071  0.17        2   -66.8160
# 44564 2023-12-31 22:13:49.174  4.20   0.4520  0.53        0   144.5892
# 44565 2023-12-31 22:48:19.016  4.40   3.4550  0.54        0  -178.3327
# 44566 2023-12-31 22:52:31.316  4.20   9.1640  0.68        0   141.4208
# 44567 2023-12-31 23:18:09.731  4.20   6.2370  0.53        0   143.5602
#
#         latitude  elevation  mag_count  mag_max  mag_mean  \
# 0     -52.770900     10.000         64      5.5  3.875938
# 1      29.653000     10.000         64      5.5  3.875938
# 2      39.603900     10.000         64      5.5  3.875938
# 3      26.794400     10.000         64      5.5  3.875938
# 4       3.142900    106.400         64      5.5  3.875938
# ...          ...        ...        ...      ...       ...
# 44563  18.064167     14.760         73      5.3  3.782055
# 44564  13.952600    193.928         73      5.3  3.782055
# 44565 -17.506500    540.654         73      5.3  3.782055
# 44566  -2.688600     10.000         73      5.3  3.782055
# 44567  -4.259000    133.548         73      5.3  3.782055
#
#        time_since_last_event_mean
# 0                     1341.188766
# 1                     1341.188766
# 2                     1341.188766
# 3                     1341.188766
# 4                     1341.188766
# ...                           ...
# 44563                 1152.619986
# 44564                 1152.619986
# 44565                 1152.619986
# 44566                 1152.619986
# 44567                 1152.619986
#
# [44568 rows x 12 columns]

# %% [markdown]
# ---
#
# # Testing

# %%
import os, sys

import pandas as pd
import numpy as np

sys.path.append(os.path.abspath('..'))

from src.helpers.datapi import generate_url_periods, url_data_call, callDataFetcher
from src.model.model import Early_Stopping, ModelCheckPoint, EarthquakeModel
from src.preprocessing.data_preprocessing import *
from src.training.training_nn import raw_data_prep, DataLoader_Conversion

# %%
df = raw_data_prep(TimeSeries=False, save=False)
# Out:
# Fetching data for period_202001...
# Fetching data for period_202006...
# Fetching data for period_202012...
# Fetching data for period_202106...
# Fetching data for period_202112...
# Fetching data for period_202206...
# Fetching data for period_202212...
# Fetching data for period_202306...
# Fetching data for period_202312...
# Fetching data for period_202406...
# Fetching data for period_202412...

# %%
df.reset_index(inplace=True)
df.drop("index", axis = 1, inplace=True)
df
# Out:
#          mag                    time     dmin   rms  magType   longitude  \
# 0       2.75 2020-01-01 00:01:56.590  0.75020  0.45        2  -67.127500
# 1       2.55 2020-01-01 00:03:38.210  0.60950  0.16        2  -67.090100
# 2       3.08 2020-01-01 00:10:43.850  0.88430  0.41        2  -67.836500
# 3       2.61 2020-01-01 00:25:35.920  0.06275  0.17        4 -155.807167
# 4       5.10 2020-01-01 00:28:20.289  1.19000  0.79        0  152.551400
# ...      ...                     ...      ...   ...      ...         ...
# 139306  4.60 2024-12-31 22:32:02.906  1.91500  0.61        0  127.264000
# 139307  4.30 2024-12-31 22:45:49.069  1.31400  0.51        0   40.000300
# 139308  4.30 2024-12-31 22:51:02.867  1.51300  0.53        0   40.207400
# 139309  5.00 2024-12-31 23:13:20.048  0.47000  0.83       13  -70.623100
# 139310  4.30 2024-12-31 23:28:55.746  3.63900  0.84        0   40.012400
#
#          latitude  elevation
# 0       19.217500      12.00
# 1       19.076600       6.00
# 2       19.193300      28.00
# 3       19.627667      12.86
# 4       -5.324500      40.24
# ...           ...        ...
# 139306   8.012700      10.00
# 139307   9.050000      10.00
# 139308   8.790500      10.00
# 139309 -20.182600      35.00
# 139310   9.177200      10.00
#
# [139311 rows x 8 columns]

# %%
data_urls = generate_url_periods(start_year=2020, end_year=2024)
    
# Fetch and combine data from all periods
earthquake_data = []
for period, url in data_urls.items():
    print(f"Fetching data for {period}...")
    period_data = url_data_call(url)
    if not period_data.empty:
        earthquake_data.append(period_data)

if earthquake_data:
    all_data = pd.concat(earthquake_data, ignore_index=True)
    all_data
# Out:
# Fetching data for period_202001...
# Fetching data for period_202006...
# Fetching data for period_202012...
# Fetching data for period_202106...
# Fetching data for period_202112...
# Fetching data for period_202206...
# Fetching data for period_202212...
# Fetching data for period_202306...
# Fetching data for period_202312...
# Fetching data for period_202406...
# Fetching data for period_202412...

# %%
df_test = data_preprocessing(all_data).copy()
df_test
# Out:
#          mag                    time     dmin   rms magType   longitude  \
# 17317   2.75 2020-01-01 00:01:56.590  0.75020  0.45      md  -67.127500
# 17316   2.55 2020-01-01 00:03:38.210  0.60950  0.16      md  -67.090100
# 17315   3.08 2020-01-01 00:10:43.850  0.88430  0.41      md  -67.836500
# 17314   2.61 2020-01-01 00:25:35.920  0.06275  0.17      ml -155.807167
# 17313   5.10 2020-01-01 00:28:20.289  1.19000  0.79      mb  152.551400
# ...      ...                     ...      ...   ...     ...         ...
# 138264  4.60 2024-12-31 22:32:02.906  1.91500  0.61      mb  127.264000
# 138263  4.30 2024-12-31 22:45:49.069  1.31400  0.51      mb   40.000300
# 138262  4.30 2024-12-31 22:51:02.867  1.51300  0.53      mb   40.207400
# 138261  5.00 2024-12-31 23:13:20.048  0.47000  0.83     mwr  -70.623100
# 138260  4.30 2024-12-31 23:28:55.746  3.63900  0.84      mb   40.012400
#
#          latitude  elevation
# 17317   19.217500      12.00
# 17316   19.076600       6.00
# 17315   19.193300      28.00
# 17314   19.627667      12.86
# 17313   -5.324500      40.24
# ...           ...        ...
# 138264   8.012700      10.00
# 138263   9.050000      10.00
# 138262   8.790500      10.00
# 138261 -20.182600      35.00
# 138260   9.177200      10.00
#
# [139311 rows x 8 columns]

# %%
df_test
# Out:
#          mag                    time     dmin   rms magType   longitude  \
# 17317   2.75 2020-01-01 00:01:56.590  0.75020  0.45      md  -67.127500
# 17316   2.55 2020-01-01 00:03:38.210  0.60950  0.16      md  -67.090100
# 17315   3.08 2020-01-01 00:10:43.850  0.88430  0.41      md  -67.836500
# 17314   2.61 2020-01-01 00:25:35.920  0.06275  0.17      ml -155.807167
# 17313   5.10 2020-01-01 00:28:20.289  1.19000  0.79      mb  152.551400
# ...      ...                     ...      ...   ...     ...         ...
# 138264  4.60 2024-12-31 22:32:02.906  1.91500  0.61      mb  127.264000
# 138263  4.30 2024-12-31 22:45:49.069  1.31400  0.51      mb   40.000300
# 138262  4.30 2024-12-31 22:51:02.867  1.51300  0.53      mb   40.207400
# 138261  5.00 2024-12-31 23:13:20.048  0.47000  0.83     mwr  -70.623100
# 138260  4.30 2024-12-31 23:28:55.746  3.63900  0.84      mb   40.012400
#
#          latitude  elevation
# 17317   19.217500      12.00
# 17316   19.076600       6.00
# 17315   19.193300      28.00
# 17314   19.627667      12.86
# 17313   -5.324500      40.24
# ...           ...        ...
# 138264   8.012700      10.00
# 138263   9.050000      10.00
# 138262   8.790500      10.00
# 138261 -20.182600      35.00
# 138260   9.177200      10.00
#
# [139311 rows x 8 columns]

# %%
all_data_filled = df_test.fillna(df_test.mean(numeric_only=True))
all_data_filled
# Out:
#          mag                    time     dmin   rms magType   longitude  \
# 17317   2.75 2020-01-01 00:01:56.590  0.75020  0.45      md  -67.127500
# 17316   2.55 2020-01-01 00:03:38.210  0.60950  0.16      md  -67.090100
# 17315   3.08 2020-01-01 00:10:43.850  0.88430  0.41      md  -67.836500
# 17314   2.61 2020-01-01 00:25:35.920  0.06275  0.17      ml -155.807167
# 17313   5.10 2020-01-01 00:28:20.289  1.19000  0.79      mb  152.551400
# ...      ...                     ...      ...   ...     ...         ...
# 138264  4.60 2024-12-31 22:32:02.906  1.91500  0.61      mb  127.264000
# 138263  4.30 2024-12-31 22:45:49.069  1.31400  0.51      mb   40.000300
# 138262  4.30 2024-12-31 22:51:02.867  1.51300  0.53      mb   40.207400
# 138261  5.00 2024-12-31 23:13:20.048  0.47000  0.83     mwr  -70.623100
# 138260  4.30 2024-12-31 23:28:55.746  3.63900  0.84      mb   40.012400
#
#          latitude  elevation
# 17317   19.217500      12.00
# 17316   19.076600       6.00
# 17315   19.193300      28.00
# 17314   19.627667      12.86
# 17313   -5.324500      40.24
# ...           ...        ...
# 138264   8.012700      10.00
# 138263   9.050000      10.00
# 138262   8.790500      10.00
# 138261 -20.182600      35.00
# 138260   9.177200      10.00
#
# [139311 rows x 8 columns]

# %%
all_data_filled.isna().sum()
# Out:
# mag          0
# time         0
# dmin         0
# rms          0
# magType      1
# longitude    0
# latitude     0
# elevation    0
# dtype: int64

# %%
df = pd.read_csv(r"C:\Projs\COde\Earthquake\eq_prediction\data\earthqukae_data.csv")
gdf = df.rename(columns={'geometry': 'geo'})
gdf
# Out:
#        Unnamed: 0                                   geo   mag  \
# 0               0     POINT Z (143.5602 -4.259 133.548)  4.20
# 1               1         POINT Z (141.4208 -2.6886 10)  4.20
# 2               2  POINT Z (-178.3327 -17.5065 540.654)  4.40
# 3               3    POINT Z (144.5892 13.9526 193.928)  4.20
# 4               4     POINT Z (-66.816 18.064167 14.76)  2.56
# ...           ...                                   ...   ...
# 18307       18307   POINT Z (-66.786167 18.948833 14.1)  3.09
# 18308       18308    POINT Z (-66.760833 18.970833 8.3)  3.13
# 18309       18309    POINT Z (-177.4335 -29.802 28.056)  5.10
# 18310       18310          POINT Z (56.6955 27.6679 10)  4.10
# 18311       18311   POINT Z (179.9588 -23.9427 503.199)  4.50
#
#                                         place           time        updated  \
# 0      60 km WSW of Angoram, Papua New Guinea  1704064689731  1709415577040
# 1         13 km E of Vanimo, Papua New Guinea  1704063151316  1709415577040
# 2                  256 km ENE of Levuka, Fiji  1704062899016  1709415577040
# 3       54 km NNW of Asan-Maina Village, Guam  1704060829174  1709415577040
# 4               4 km NE of Yauco, Puerto Rico  1704058947330  1704059936640
# ...                                       ...            ...            ...
# 18307                      Puerto Rico region  1682902140850  1682903828880
# 18308         54 km N of Hatillo, Puerto Rico  1682902013270  1682903065390
# 18309           Kermadec Islands, New Zealand  1682900180641  1689459041040
# 18310          67 km NE of Bandar Abbas, Iran  1682900019447  1689459041040
# 18311               south of the Fiji Islands  1682899759473  1689458993040
#
#        tz                                                url  \
# 0     NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 1     NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 2     NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 3     NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 4     NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# ...    ..                                                ...
# 18307 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 18308 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 18309 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 18310 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 18311 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                   detail  felt  ...  \
# 0      https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...
# 1      https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...
# 2      https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...
# 3      https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...
# 4      https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...
# ...                                                  ...   ...  ...
# 18307  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...
# 18308  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...
# 18309  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...
# 18310  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...
# 18311  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  ...
#
#                 ids  sources                types   nst    dmin   rms    gap  \
# 0      ,us6000m2x9,     ,us,  ,origin,phase-data,  40.0  6.2370  0.53  117.0
# 1      ,us6000m2x8,     ,us,  ,origin,phase-data,  26.0  9.1640  0.68   78.0
# 2      ,us6000m2x7,     ,us,  ,origin,phase-data,  46.0  3.4550  0.54   49.0
# 3      ,us6000m2x5,     ,us,  ,origin,phase-data,  38.0  0.4520  0.53  100.0
# 4      ,pr71435938,     ,pr,  ,origin,phase-data,  14.0  0.1071  0.17   93.0
# ...             ...      ...                  ...   ...     ...   ...    ...
# 18307  ,pr71407338,     ,pr,  ,origin,phase-data,  10.0  0.5998  0.21  261.0
# 18308  ,pr71407353,     ,pr,  ,origin,phase-data,   5.0  0.6209  0.26  328.0
# 18309  ,us7000jx9j,     ,us,  ,origin,phase-data,  72.0  0.6850  0.66   75.0
# 18310  ,us7000jx9i,     ,us,  ,origin,phase-data,  65.0  2.7470  0.74  140.0
# 18311  ,us6000k9rv,     ,us,  ,origin,phase-data,  30.0  5.2540  0.51  101.0
#
#       magType        type                                           title
# 0          mb  earthquake  M 4.2 - 60 km WSW of Angoram, Papua New Guinea
# 1          mb  earthquake     M 4.2 - 13 km E of Vanimo, Papua New Guinea
# 2          mb  earthquake              M 4.4 - 256 km ENE of Levuka, Fiji
# 3          mb  earthquake   M 4.2 - 54 km NNW of Asan-Maina Village, Guam
# 4          md  earthquake           M 2.6 - 4 km NE of Yauco, Puerto Rico
# ...       ...         ...                                             ...
# 18307      md  earthquake                      M 3.1 - Puerto Rico region
# 18308      md  earthquake         M 3.1 - 54 km N of Hatillo, Puerto Rico
# 18309     mww  earthquake           M 5.1 - Kermadec Islands, New Zealand
# 18310      mb  earthquake          M 4.1 - 67 km NE of Bandar Abbas, Iran
# 18311      mb  earthquake               M 4.5 - south of the Fiji Islands
#
# [18312 rows x 28 columns]

# %%
data2 = gdf.drop(columns=[
    'tz', 'url',
    'detail', 'felt', 
    'cdi', 'mmi', 'alert',
    'status', 'tsunami', 'sig',
    'net', 'code', 'ids',
    'sources', 'sources', 'nst',
    'title', 'types', 'gap', 'updated'
])

data2
# Out:
#        Unnamed: 0                                   geo   mag  \
# 0               0     POINT Z (143.5602 -4.259 133.548)  4.20
# 1               1         POINT Z (141.4208 -2.6886 10)  4.20
# 2               2  POINT Z (-178.3327 -17.5065 540.654)  4.40
# 3               3    POINT Z (144.5892 13.9526 193.928)  4.20
# 4               4     POINT Z (-66.816 18.064167 14.76)  2.56
# ...           ...                                   ...   ...
# 18307       18307   POINT Z (-66.786167 18.948833 14.1)  3.09
# 18308       18308    POINT Z (-66.760833 18.970833 8.3)  3.13
# 18309       18309    POINT Z (-177.4335 -29.802 28.056)  5.10
# 18310       18310          POINT Z (56.6955 27.6679 10)  4.10
# 18311       18311   POINT Z (179.9588 -23.9427 503.199)  4.50
#
#                                         place           time    dmin   rms  \
# 0      60 km WSW of Angoram, Papua New Guinea  1704064689731  6.2370  0.53
# 1         13 km E of Vanimo, Papua New Guinea  1704063151316  9.1640  0.68
# 2                  256 km ENE of Levuka, Fiji  1704062899016  3.4550  0.54
# 3       54 km NNW of Asan-Maina Village, Guam  1704060829174  0.4520  0.53
# 4               4 km NE of Yauco, Puerto Rico  1704058947330  0.1071  0.17
# ...                                       ...            ...     ...   ...
# 18307                      Puerto Rico region  1682902140850  0.5998  0.21
# 18308         54 km N of Hatillo, Puerto Rico  1682902013270  0.6209  0.26
# 18309           Kermadec Islands, New Zealand  1682900180641  0.6850  0.66
# 18310          67 km NE of Bandar Abbas, Iran  1682900019447  2.7470  0.74
# 18311               south of the Fiji Islands  1682899759473  5.2540  0.51
#
#       magType        type
# 0          mb  earthquake
# 1          mb  earthquake
# 2          mb  earthquake
# 3          mb  earthquake
# 4          md  earthquake
# ...       ...         ...
# 18307      md  earthquake
# 18308      md  earthquake
# 18309     mww  earthquake
# 18310      mb  earthquake
# 18311      mb  earthquake
#
# [18312 rows x 9 columns]

# %%
if "Unnamed: 0" in data2.columns:
    print("Yes")
    data2.drop("Unnamed: 0", axis=1, inplace=True)

data2
# Out:
# Yes
#                                         geo   mag  \
# 0         POINT Z (143.5602 -4.259 133.548)  4.20
# 1             POINT Z (141.4208 -2.6886 10)  4.20
# 2      POINT Z (-178.3327 -17.5065 540.654)  4.40
# 3        POINT Z (144.5892 13.9526 193.928)  4.20
# 4         POINT Z (-66.816 18.064167 14.76)  2.56
# ...                                     ...   ...
# 18307   POINT Z (-66.786167 18.948833 14.1)  3.09
# 18308    POINT Z (-66.760833 18.970833 8.3)  3.13
# 18309    POINT Z (-177.4335 -29.802 28.056)  5.10
# 18310          POINT Z (56.6955 27.6679 10)  4.10
# 18311   POINT Z (179.9588 -23.9427 503.199)  4.50
#
#                                         place           time    dmin   rms  \
# 0      60 km WSW of Angoram, Papua New Guinea  1704064689731  6.2370  0.53
# 1         13 km E of Vanimo, Papua New Guinea  1704063151316  9.1640  0.68
# 2                  256 km ENE of Levuka, Fiji  1704062899016  3.4550  0.54
# 3       54 km NNW of Asan-Maina Village, Guam  1704060829174  0.4520  0.53
# 4               4 km NE of Yauco, Puerto Rico  1704058947330  0.1071  0.17
# ...                                       ...            ...     ...   ...
# 18307                      Puerto Rico region  1682902140850  0.5998  0.21
# 18308         54 km N of Hatillo, Puerto Rico  1682902013270  0.6209  0.26
# 18309           Kermadec Islands, New Zealand  1682900180641  0.6850  0.66
# 18310          67 km NE of Bandar Abbas, Iran  1682900019447  2.7470  0.74
# 18311               south of the Fiji Islands  1682899759473  5.2540  0.51
#
#       magType        type
# 0          mb  earthquake
# 1          mb  earthquake
# 2          mb  earthquake
# 3          mb  earthquake
# 4          md  earthquake
# ...       ...         ...
# 18307      md  earthquake
# 18308      md  earthquake
# 18309     mww  earthquake
# 18310      mb  earthquake
# 18311      mb  earthquake
#
# [18312 rows x 8 columns]

# %%
eq_data = data2.loc[data2['type'] == 'earthquake']
eq_data
# Out:
#                                         geo   mag  \
# 0         POINT Z (143.5602 -4.259 133.548)  4.20
# 1             POINT Z (141.4208 -2.6886 10)  4.20
# 2      POINT Z (-178.3327 -17.5065 540.654)  4.40
# 3        POINT Z (144.5892 13.9526 193.928)  4.20
# 4         POINT Z (-66.816 18.064167 14.76)  2.56
# ...                                     ...   ...
# 18307   POINT Z (-66.786167 18.948833 14.1)  3.09
# 18308    POINT Z (-66.760833 18.970833 8.3)  3.13
# 18309    POINT Z (-177.4335 -29.802 28.056)  5.10
# 18310          POINT Z (56.6955 27.6679 10)  4.10
# 18311   POINT Z (179.9588 -23.9427 503.199)  4.50
#
#                                         place           time    dmin   rms  \
# 0      60 km WSW of Angoram, Papua New Guinea  1704064689731  6.2370  0.53
# 1         13 km E of Vanimo, Papua New Guinea  1704063151316  9.1640  0.68
# 2                  256 km ENE of Levuka, Fiji  1704062899016  3.4550  0.54
# 3       54 km NNW of Asan-Maina Village, Guam  1704060829174  0.4520  0.53
# 4               4 km NE of Yauco, Puerto Rico  1704058947330  0.1071  0.17
# ...                                       ...            ...     ...   ...
# 18307                      Puerto Rico region  1682902140850  0.5998  0.21
# 18308         54 km N of Hatillo, Puerto Rico  1682902013270  0.6209  0.26
# 18309           Kermadec Islands, New Zealand  1682900180641  0.6850  0.66
# 18310          67 km NE of Bandar Abbas, Iran  1682900019447  2.7470  0.74
# 18311               south of the Fiji Islands  1682899759473  5.2540  0.51
#
#       magType        type
# 0          mb  earthquake
# 1          mb  earthquake
# 2          mb  earthquake
# 3          mb  earthquake
# 4          md  earthquake
# ...       ...         ...
# 18307      md  earthquake
# 18308      md  earthquake
# 18309     mww  earthquake
# 18310      mb  earthquake
# 18311      mb  earthquake
#
# [18144 rows x 8 columns]

# %%
eq_data = eq_data.copy()
eq_data.drop('type', axis=1, inplace=True)
eq_data.reset_index(inplace=True,drop=True)
eq_data
# Out:
#                                         geo   mag  \
# 0         POINT Z (143.5602 -4.259 133.548)  4.20
# 1             POINT Z (141.4208 -2.6886 10)  4.20
# 2      POINT Z (-178.3327 -17.5065 540.654)  4.40
# 3        POINT Z (144.5892 13.9526 193.928)  4.20
# 4         POINT Z (-66.816 18.064167 14.76)  2.56
# ...                                     ...   ...
# 18139   POINT Z (-66.786167 18.948833 14.1)  3.09
# 18140    POINT Z (-66.760833 18.970833 8.3)  3.13
# 18141    POINT Z (-177.4335 -29.802 28.056)  5.10
# 18142          POINT Z (56.6955 27.6679 10)  4.10
# 18143   POINT Z (179.9588 -23.9427 503.199)  4.50
#
#                                         place           time    dmin   rms  \
# 0      60 km WSW of Angoram, Papua New Guinea  1704064689731  6.2370  0.53
# 1         13 km E of Vanimo, Papua New Guinea  1704063151316  9.1640  0.68
# 2                  256 km ENE of Levuka, Fiji  1704062899016  3.4550  0.54
# 3       54 km NNW of Asan-Maina Village, Guam  1704060829174  0.4520  0.53
# 4               4 km NE of Yauco, Puerto Rico  1704058947330  0.1071  0.17
# ...                                       ...            ...     ...   ...
# 18139                      Puerto Rico region  1682902140850  0.5998  0.21
# 18140         54 km N of Hatillo, Puerto Rico  1682902013270  0.6209  0.26
# 18141           Kermadec Islands, New Zealand  1682900180641  0.6850  0.66
# 18142          67 km NE of Bandar Abbas, Iran  1682900019447  2.7470  0.74
# 18143               south of the Fiji Islands  1682899759473  5.2540  0.51
#
#       magType
# 0          mb
# 1          mb
# 2          mb
# 3          mb
# 4          md
# ...       ...
# 18139      md
# 18140      md
# 18141     mww
# 18142      mb
# 18143      mb
#
# [18144 rows x 7 columns]

# %%
eq_data
# Out:
#                                         geo   mag  \
# 0         POINT Z (143.5602 -4.259 133.548)  4.20
# 1             POINT Z (141.4208 -2.6886 10)  4.20
# 2      POINT Z (-178.3327 -17.5065 540.654)  4.40
# 3        POINT Z (144.5892 13.9526 193.928)  4.20
# 4         POINT Z (-66.816 18.064167 14.76)  2.56
# ...                                     ...   ...
# 18139   POINT Z (-66.786167 18.948833 14.1)  3.09
# 18140    POINT Z (-66.760833 18.970833 8.3)  3.13
# 18141    POINT Z (-177.4335 -29.802 28.056)  5.10
# 18142          POINT Z (56.6955 27.6679 10)  4.10
# 18143   POINT Z (179.9588 -23.9427 503.199)  4.50
#
#                                         place           time    dmin   rms  \
# 0      60 km WSW of Angoram, Papua New Guinea  1704064689731  6.2370  0.53
# 1         13 km E of Vanimo, Papua New Guinea  1704063151316  9.1640  0.68
# 2                  256 km ENE of Levuka, Fiji  1704062899016  3.4550  0.54
# 3       54 km NNW of Asan-Maina Village, Guam  1704060829174  0.4520  0.53
# 4               4 km NE of Yauco, Puerto Rico  1704058947330  0.1071  0.17
# ...                                       ...            ...     ...   ...
# 18139                      Puerto Rico region  1682902140850  0.5998  0.21
# 18140         54 km N of Hatillo, Puerto Rico  1682902013270  0.6209  0.26
# 18141           Kermadec Islands, New Zealand  1682900180641  0.6850  0.66
# 18142          67 km NE of Bandar Abbas, Iran  1682900019447  2.7470  0.74
# 18143               south of the Fiji Islands  1682899759473  5.2540  0.51
#
#       magType
# 0          mb
# 1          mb
# 2          mb
# 3          mb
# 4          md
# ...       ...
# 18139      md
# 18140      md
# 18141     mww
# 18142      mb
# 18143      mb
#
# [18144 rows x 7 columns]

# %%
eq_data['time'] = pd.to_datetime(eq_data['time'], unit='ms')
eq_data
# Out:
#                                         geo   mag  \
# 0         POINT Z (143.5602 -4.259 133.548)  4.20
# 1             POINT Z (141.4208 -2.6886 10)  4.20
# 2      POINT Z (-178.3327 -17.5065 540.654)  4.40
# 3        POINT Z (144.5892 13.9526 193.928)  4.20
# 4         POINT Z (-66.816 18.064167 14.76)  2.56
# ...                                     ...   ...
# 18139   POINT Z (-66.786167 18.948833 14.1)  3.09
# 18140    POINT Z (-66.760833 18.970833 8.3)  3.13
# 18141    POINT Z (-177.4335 -29.802 28.056)  5.10
# 18142          POINT Z (56.6955 27.6679 10)  4.10
# 18143   POINT Z (179.9588 -23.9427 503.199)  4.50
#
#                                         place                    time    dmin  \
# 0      60 km WSW of Angoram, Papua New Guinea 2023-12-31 23:18:09.731  6.2370
# 1         13 km E of Vanimo, Papua New Guinea 2023-12-31 22:52:31.316  9.1640
# 2                  256 km ENE of Levuka, Fiji 2023-12-31 22:48:19.016  3.4550
# 3       54 km NNW of Asan-Maina Village, Guam 2023-12-31 22:13:49.174  0.4520
# 4               4 km NE of Yauco, Puerto Rico 2023-12-31 21:42:27.330  0.1071
# ...                                       ...                     ...     ...
# 18139                      Puerto Rico region 2023-05-01 00:49:00.850  0.5998
# 18140         54 km N of Hatillo, Puerto Rico 2023-05-01 00:46:53.270  0.6209
# 18141           Kermadec Islands, New Zealand 2023-05-01 00:16:20.641  0.6850
# 18142          67 km NE of Bandar Abbas, Iran 2023-05-01 00:13:39.447  2.7470
# 18143               south of the Fiji Islands 2023-05-01 00:09:19.473  5.2540
#
#         rms magType
# 0      0.53      mb
# 1      0.68      mb
# 2      0.54      mb
# 3      0.53      mb
# 4      0.17      md
# ...     ...     ...
# 18139  0.21      md
# 18140  0.26      md
# 18141  0.66     mww
# 18142  0.74      mb
# 18143  0.51      mb
#
# [18144 rows x 7 columns]

# %%
eq_data['geo'][0].split()[2:]

def split_and_slice(series, split_char=" ", start_idx=2, end_idx=None):
    """
    Splits each string in the series by `split_char` and returns the slice [start_idx:end_idx].
    """
    return series.apply(lambda x: x.split(split_char)[start_idx:end_idx] if isinstance(x, str) else x)

# Example usage:
split_parts = split_and_slice(eq_data['geo'], split_char=" ", start_idx=2)

# %%
def split_and_slice(series, split_char=" ", start_idx=2, end_idx=None):
    """
    Splits each string in the series by `split_char` and returns the slice [start_idx:end_idx].
    """
    T_df = series.apply(lambda x: x.split(split_char)[start_idx:end_idx] if isinstance(x, str) else x)

    # Create an empty DataFrame with specific columns for latitude, longitude, and depth
    dummy_df = pd.DataFrame(columns=['longitude', 'latitude', 'depth'])

    # Append each row as a new row in the DataFrame, assigning to specific columns
    for x in T_df:
        if isinstance(x, list) and len(x) == 3:
            # Remove parentheses and convert to float
            lon = str(x[0]).replace('(', '').strip()
            lat = str(x[1]).strip()
            depth = str(x[2]).replace(')', '').strip()
            dummy_df = pd.concat(
                [dummy_df, pd.DataFrame([{
                    'longitude': float(lon),
                    'latitude': float(lat),
                    'depth': float(depth)
                }])],
                ignore_index=True
            )
        
    return dummy_df

# %%
test_df = split_and_slice(eq_data['geo'])
# Out:
# C:\Users\Rishi\AppData\Local\Temp\ipykernel_13532\141277465.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dummy_df = pd.concat(

# %%
test_df['checker_counter'] = range(len(test_df))
test_df
# Out:
#         longitude   latitude    depth  checker_counter
# 0      143.560200  -4.259000  133.548                0
# 1      141.420800  -2.688600   10.000                1
# 2     -178.332700 -17.506500  540.654                2
# 3      144.589200  13.952600  193.928                3
# 4      -66.816000  18.064167   14.760                4
# ...           ...        ...      ...              ...
# 18139  -66.786167  18.948833   14.100            18139
# 18140  -66.760833  18.970833    8.300            18140
# 18141 -177.433500 -29.802000   28.056            18141
# 18142   56.695500  27.667900   10.000            18142
# 18143  179.958800 -23.942700  503.199            18143
#
# [18144 rows x 4 columns]

# %%
raw_data_prep(TimeSeries=False, save=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 raw_data_prep(TimeSeries=False, save=False)
#
# File c:\Projs\COde\Earthquake\eq_prediction\src\training\training_nn.py:34, in raw_data_prep(TimeSeries, save)
#      30 def raw_data_prep(TimeSeries: bool, save: bool = False) -> pd.DataFrame:
#      31     """
#      32     Calls and defines the data and returns a Pandas DataFrame with basic preprocssing.
#      33     """
# ---> 34     df = pd.concat([url_data_call(datas[key], save) for key in datas], ignore_index=True)
#      36     dff = data_preprocessing(df, ts=TimeSeries) ## This function performs basic proecprocessing with an option of Timeseries or not.
#      37     dff = imput_encode(dff) ## This function encodes and imputs the input data and fills the empty values.
#
# File c:\Projs\COde\Earthquake\eq_prediction\src\training\training_nn.py:34, in <listcomp>(.0)
#      30 def raw_data_prep(TimeSeries: bool, save: bool = False) -> pd.DataFrame:
#      31     """
#      32     Calls and defines the data and returns a Pandas DataFrame with basic preprocssing.
#      33     """
# ---> 34     df = pd.concat([url_data_call(datas[key], save) for key in datas], ignore_index=True)
#      36     dff = data_preprocessing(df, ts=TimeSeries) ## This function performs basic proecprocessing with an option of Timeseries or not.
#      37     dff = imput_encode(dff) ## This function encodes and imputs the input data and fills the empty values.
#
# File c:\Projs\COde\Earthquake\eq_prediction\src\helpers\datapi.py:41, in url_data_call(stored_data, URL)
#      38 def url_data_call(stored_data: bool = False, URL = None) -> pd.DataFrame:
#      39     if stored_data:
#      40         # Load dataset
# ---> 41         df = pd.read_csv(r".\data\earthqukae_data.csv")
#      42         gdf = df.rename(columns={'geometry': 'geo'})
#      44         return gdf
#
# File c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '.\\data\\earthqukae_data.csv'

# %%
fin_test_df = pd.concat([eq_data, test_df], ignore_index = True, axis=1)
fin_test_df
# Out:
#                                           0     1  \
# 0         POINT Z (143.5602 -4.259 133.548)  4.20
# 1             POINT Z (141.4208 -2.6886 10)  4.20
# 2      POINT Z (-178.3327 -17.5065 540.654)  4.40
# 3        POINT Z (144.5892 13.9526 193.928)  4.20
# 4         POINT Z (-66.816 18.064167 14.76)  2.56
# ...                                     ...   ...
# 18139   POINT Z (-66.786167 18.948833 14.1)  3.09
# 18140    POINT Z (-66.760833 18.970833 8.3)  3.13
# 18141    POINT Z (-177.4335 -29.802 28.056)  5.10
# 18142          POINT Z (56.6955 27.6679 10)  4.10
# 18143   POINT Z (179.9588 -23.9427 503.199)  4.50
#
#                                             2                       3       4  \
# 0      60 km WSW of Angoram, Papua New Guinea 2023-12-31 23:18:09.731  6.2370
# 1         13 km E of Vanimo, Papua New Guinea 2023-12-31 22:52:31.316  9.1640
# 2                  256 km ENE of Levuka, Fiji 2023-12-31 22:48:19.016  3.4550
# 3       54 km NNW of Asan-Maina Village, Guam 2023-12-31 22:13:49.174  0.4520
# 4               4 km NE of Yauco, Puerto Rico 2023-12-31 21:42:27.330  0.1071
# ...                                       ...                     ...     ...
# 18139                      Puerto Rico region 2023-05-01 00:49:00.850  0.5998
# 18140         54 km N of Hatillo, Puerto Rico 2023-05-01 00:46:53.270  0.6209
# 18141           Kermadec Islands, New Zealand 2023-05-01 00:16:20.641  0.6850
# 18142          67 km NE of Bandar Abbas, Iran 2023-05-01 00:13:39.447  2.7470
# 18143               south of the Fiji Islands 2023-05-01 00:09:19.473  5.2540
#
#           5    6           7          8        9
# 0      0.53   mb  143.560200  -4.259000  133.548
# 1      0.68   mb  141.420800  -2.688600   10.000
# 2      0.54   mb -178.332700 -17.506500  540.654
# 3      0.53   mb  144.589200  13.952600  193.928
# 4      0.17   md  -66.816000  18.064167   14.760
# ...     ...  ...         ...        ...      ...
# 18139  0.21   md  -66.786167  18.948833   14.100
# 18140  0.26   md  -66.760833  18.970833    8.300
# 18141  0.66  mww -177.433500 -29.802000   28.056
# 18142  0.74   mb   56.695500  27.667900   10.000
# 18143  0.51   mb  179.958800 -23.942700  503.199
#
# [18144 rows x 10 columns]

# %%
eq_data
# Out:
#                                         geo   mag  \
# 0         POINT Z (143.5602 -4.259 133.548)  4.20
# 1             POINT Z (141.4208 -2.6886 10)  4.20
# 2      POINT Z (-178.3327 -17.5065 540.654)  4.40
# 3        POINT Z (144.5892 13.9526 193.928)  4.20
# 4         POINT Z (-66.816 18.064167 14.76)  2.56
# ...                                     ...   ...
# 18307   POINT Z (-66.786167 18.948833 14.1)  3.09
# 18308    POINT Z (-66.760833 18.970833 8.3)  3.13
# 18309    POINT Z (-177.4335 -29.802 28.056)  5.10
# 18310          POINT Z (56.6955 27.6679 10)  4.10
# 18311   POINT Z (179.9588 -23.9427 503.199)  4.50
#
#                                         place                    time    dmin  \
# 0      60 km WSW of Angoram, Papua New Guinea 2023-12-31 23:18:09.731  6.2370
# 1         13 km E of Vanimo, Papua New Guinea 2023-12-31 22:52:31.316  9.1640
# 2                  256 km ENE of Levuka, Fiji 2023-12-31 22:48:19.016  3.4550
# 3       54 km NNW of Asan-Maina Village, Guam 2023-12-31 22:13:49.174  0.4520
# 4               4 km NE of Yauco, Puerto Rico 2023-12-31 21:42:27.330  0.1071
# ...                                       ...                     ...     ...
# 18307                      Puerto Rico region 2023-05-01 00:49:00.850  0.5998
# 18308         54 km N of Hatillo, Puerto Rico 2023-05-01 00:46:53.270  0.6209
# 18309           Kermadec Islands, New Zealand 2023-05-01 00:16:20.641  0.6850
# 18310          67 km NE of Bandar Abbas, Iran 2023-05-01 00:13:39.447  2.7470
# 18311               south of the Fiji Islands 2023-05-01 00:09:19.473  5.2540
#
#         rms magType
# 0      0.53      mb
# 1      0.68      mb
# 2      0.54      mb
# 3      0.53      mb
# 4      0.17      md
# ...     ...     ...
# 18307  0.21      md
# 18308  0.26      md
# 18309  0.66     mww
# 18310  0.74      mb
# 18311  0.51      mb
#
# [18144 rows x 7 columns]

# %%
fin_test_df = eq_data.copy()
fin_test_df = pd.concat([fin_test_df, test_df], ignore_index = True, axis=1)
fin_test_df
# Out:
#                                          0     1   \
# 0         POINT Z (143.5602 -4.259 133.548)  4.20
# 1             POINT Z (141.4208 -2.6886 10)  4.20
# 2      POINT Z (-178.3327 -17.5065 540.654)  4.40
# 3        POINT Z (144.5892 13.9526 193.928)  4.20
# 4         POINT Z (-66.816 18.064167 14.76)  2.56
# ...                                     ...   ...
# 17781                                   NaN   NaN
# 17782                                   NaN   NaN
# 17903                                   NaN   NaN
# 18046                                   NaN   NaN
# 18049                                   NaN   NaN
#
#                                            2                       3       4   \
# 0      60 km WSW of Angoram, Papua New Guinea 2023-12-31 23:18:09.731  6.2370
# 1         13 km E of Vanimo, Papua New Guinea 2023-12-31 22:52:31.316  9.1640
# 2                  256 km ENE of Levuka, Fiji 2023-12-31 22:48:19.016  3.4550
# 3       54 km NNW of Asan-Maina Village, Guam 2023-12-31 22:13:49.174  0.4520
# 4               4 km NE of Yauco, Puerto Rico 2023-12-31 21:42:27.330  0.1071
# ...                                       ...                     ...     ...
# 17781                                     NaN                     NaT     NaN
# 17782                                     NaN                     NaT     NaN
# 17903                                     NaN                     NaT     NaN
# 18046                                     NaN                     NaT     NaN
# 18049                                     NaN                     NaT     NaN
#
#          5    6           7          8        9        10
# 0      0.53   mb  143.560200  -4.259000  133.548      0.0
# 1      0.68   mb  141.420800  -2.688600   10.000      1.0
# 2      0.54   mb -178.332700 -17.506500  540.654      2.0
# 3      0.53   mb  144.589200  13.952600  193.928      3.0
# 4      0.17   md  -66.816000  18.064167   14.760      4.0
# ...     ...  ...         ...        ...      ...      ...
# 17781   NaN  NaN  -72.989400   6.760800  153.560  17781.0
# 17782   NaN  NaN  179.896300 -24.614800  489.231  17782.0
# 17903   NaN  NaN -155.487500  19.167500   31.160  17903.0
# 18046   NaN  NaN  145.390300  14.846100  257.506  18046.0
# 18049   NaN  NaN -124.232333  41.194500   16.310  18049.0
#
# [18312 rows x 11 columns]

# %%
# eq_data['coords'] = eq_data['geo'].apply(lambda geom: list(geom.coords))

# %% [markdown]
# ## New Data Manipulation Testing

# %%
df = callDataFetcher()
# Out:
# Fetching data for period_202001...
# Fetching data for period_202006...
# Fetching data for period_202012...
# Fetching data for period_202106...
# Fetching data for period_202112...
# Fetching data for period_202206...
# Fetching data for period_202212...
# Fetching data for period_202306...
# Fetching data for period_202312...
# Fetching data for period_202406...
# Fetching data for period_202412...

# %%
df.head(10)
# Out:
#                                   geo   mag  \
# 0        POINT Z (-68.4283 19.575 10)  3.00
# 1        POINT Z (-66.9495 17.934 13)  3.64
# 2    POINT Z (-150.9755 61.0827 53.6)  2.50
# 3        POINT Z (-66.955 17.9391 12)  3.02
# 4  POINT Z (-173.8901 52.4679 130.54)  3.80
# 5       POINT Z (-66.9495 17.9443 13)  4.50
# 6       POINT Z (-66.9603 17.9356 13)  3.16
# 7        POINT Z (-66.9626 17.937 13)  3.03
# 8       POINT Z (-66.9621 17.9548 13)  2.59
# 9         POINT Z (-66.928 17.942 12)  3.01
#
#                                     place           time        updated    tz  \
# 0  92 km NE of Miches, Dominican Republic  1593386756400  1599327331040  None
# 1         6 km SW of Guánica, Puerto Rico  1593385968350  1599327331040  None
# 2               8 km SE of Beluga, Alaska  1593385936705  1599327331040  None
# 3         6 km SW of Guánica, Puerto Rico  1593385741590  1599327331040  None
# 4                36 km NE of Atka, Alaska  1593384708681  1599327342040  None
# 5         5 km SW of Guánica, Puerto Rico  1593384529670  1599327331040  None
# 6         6 km SW of Guánica, Puerto Rico  1593384098970  1599327331040  None
# 7        7 km WSW of Guánica, Puerto Rico  1593383656360  1599327331040  None
# 8        6 km WSW of Guánica, Puerto Rico  1593383330860  1593531206250  None
# 9        3 km SSW of Guánica, Puerto Rico  1593383094320  1599327331040  None
#
#                                                  url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
# 5  https://earthquake.usgs.gov/earthquakes/eventp...
# 6  https://earthquake.usgs.gov/earthquakes/eventp...
# 7  https://earthquake.usgs.gov/earthquakes/eventp...
# 8  https://earthquake.usgs.gov/earthquakes/eventp...
# 9  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail   felt  cdi  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...    NaN  NaN  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...   10.0  4.1  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...    NaN  NaN  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...    NaN  NaN  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...    NaN  NaN  ...
# 5  https://earthquake.usgs.gov/fdsnws/event/1/que...  173.0  4.8  ...
# 6  https://earthquake.usgs.gov/fdsnws/event/1/que...    NaN  NaN  ...
# 7  https://earthquake.usgs.gov/fdsnws/event/1/que...    NaN  NaN  ...
# 8  https://earthquake.usgs.gov/fdsnws/event/1/que...    NaN  NaN  ...
# 9  https://earthquake.usgs.gov/fdsnws/event/1/que...    1.0  2.0  ...
#
#                                     ids     sources  \
# 0                          ,us7000adyb,        ,us,
# 1  ,us7000adxu,pr2020180033,pt20180053,  ,us,pr,pt,
# 2             ,us7000adxv,ak0208a2i1n5,     ,us,ak,
# 3             ,us7000adxr,pr2020180034,     ,us,pr,
# 4             ,ak0208a251i5,us7000ahfq,     ,ak,us,
# 5  ,pt20180052,us7000adx7,pr2020180032,  ,pt,us,pr,
# 6             ,us7000adx3,pr2020180030,     ,us,pr,
# 7             ,us7000adwz,pr2020180036,     ,us,pr,
# 8                        ,pr2020180067,        ,pr,
# 9             ,us7000adww,pr2020180035,     ,us,pr,
#
#                                                types   nst    dmin   rms  \
# 0                                ,origin,phase-data,   NaN  1.9980  0.47
# 1  ,dyfi,internal-origin,moment-tensor,origin,pha...  21.0  0.0814  0.18
# 2                                ,origin,phase-data,   NaN     NaN  0.51
# 3                                ,origin,phase-data,  23.0  0.0839  0.20
# 4                                ,origin,phase-data,   NaN  0.1570  0.74
# 5  ,dyfi,internal-origin,losspager,moment-tensor,...  31.0  0.0980  0.13
# 6                                ,origin,phase-data,  23.0  0.0902  0.21
# 7                                ,origin,phase-data,  23.0  0.0878  0.11
# 8                                ,origin,phase-data,  18.0  0.0834  0.16
# 9                           ,dyfi,origin,phase-data,  23.0  0.0590  0.14
#
#      gap magType        type                                           title
# 0  348.0      ml  earthquake  M 3.0 - 92 km NE of Miches, Dominican Republic
# 1  212.0      ml  earthquake         M 3.6 - 6 km SW of Guánica, Puerto Rico
# 2    NaN      ml  earthquake               M 2.5 - 8 km SE of Beluga, Alaska
# 3  209.0      md  earthquake         M 3.0 - 6 km SW of Guánica, Puerto Rico
# 4  124.0      mb  earthquake                M 3.8 - 36 km NE of Atka, Alaska
# 5  204.0      ml  earthquake         M 4.5 - 5 km SW of Guánica, Puerto Rico
# 6  212.0      md  earthquake         M 3.2 - 6 km SW of Guánica, Puerto Rico
# 7  212.0      md  earthquake        M 3.0 - 7 km WSW of Guánica, Puerto Rico
# 8  196.0      md  earthquake        M 2.6 - 6 km WSW of Guánica, Puerto Rico
# 9  196.0      md  earthquake        M 3.0 - 3 km SSW of Guánica, Puerto Rico
#
# [10 rows x 27 columns]

# %%
# This function creates a new dataframe with event counts for different windows.
def event_counts_for_diff_window2(dataFrame: pd.DataFrame, filler = "mean") -> pd.DataFrame:
    """
    This function creates a new dataframe with event counts for different time windows.
    
    It performs the following operations:
    1. Sorts the input dataframe by time
    2. Calculates the time since the last event
    3. Fills NaN values in numeric columns
    4. Creates daily aggregations (count, max, mean of magnitudes, and time span)
    5. Encodes latitude and longitude bins
    6. Merges daily features back to the original dataframe
    
    The function aims to enrich the earthquake data with temporal and spatial features,
    which can be useful for further analysis or modeling of earthquake patterns.
    """
    new_df = dataFrame.copy()

    new_df =  new_df.sort_values('time')

    if 'time' in dataFrame.index.names:
        new_df = new_df.reset_index(drop=False)

    new_df['time_since_last_event'] = new_df['time'].diff().dt.total_seconds()

    numeric_columns = new_df.select_dtypes(include=[np.number]).columns
    if filler == "mean":
        new_df[numeric_columns] = new_df[numeric_columns].fillna(new_df[numeric_columns].mean())
    else:
        # Fill NaN values only for non-categorical columns
        new_df[numeric_columns] = new_df[numeric_columns].fillna(0)

    daily_df = new_df.resample('D', on='time').agg({
        'mag': ['count', 'max', 'mean'],
        'time': lambda x: (x.max() - x.min()).total_seconds()
    })

    daily_df.columns = ['_'.join(col).strip() for col in daily_df.columns.values]
    daily_df = daily_df.reset_index()

    new_df = encode_lat_lon_bins(df=new_df)

    # Merge daily features back to original DataFrame
    new_df = pd.merge_asof(new_df, daily_df, left_on='time', right_on='time', 
                   tolerance=pd.Timedelta('1D'), direction='backward')
    return new_df

# %%
df2 = df.copy()
df2 = data_preprocessing(df, ts=True)
df2.head(10)
# Out:
#                           mag     dmin   rms magType   longitude   latitude  \
# time
# 2020-01-01 00:01:56.590  2.75  0.75020  0.45      md  -67.127500  19.217500
# 2020-01-01 00:03:38.210  2.55  0.60950  0.16      md  -67.090100  19.076600
# 2020-01-01 00:10:43.850  3.08  0.88430  0.41      md  -67.836500  19.193300
# 2020-01-01 00:25:35.920  2.61  0.06275  0.17      ml -155.807167  19.627667
# 2020-01-01 00:28:20.289  5.10  1.19000  0.79      mb  152.551400  -5.324500
# 2020-01-01 00:35:48.020  4.60  1.21800  1.08      mb  152.600300  -5.337300
# 2020-01-01 00:38:00.890  2.80  0.11580  0.23      md  -66.831100  17.869800
# 2020-01-01 00:57:01.290  2.67  0.96080  0.44      md  -67.210500  19.128500
# 2020-01-01 01:00:32.490  2.64  0.96880  0.21      md  -66.266800  18.693300
# 2020-01-01 01:08:54.688  4.50  1.47800  0.65      mb  138.330900  32.287900
#
#                          elevation
# time
# 2020-01-01 00:01:56.590      12.00
# 2020-01-01 00:03:38.210       6.00
# 2020-01-01 00:10:43.850      28.00
# 2020-01-01 00:25:35.920      12.86
# 2020-01-01 00:28:20.289      40.24
# 2020-01-01 00:35:48.020      32.93
# 2020-01-01 00:38:00.890       7.00
# 2020-01-01 00:57:01.290       8.00
# 2020-01-01 01:00:32.490      29.00
# 2020-01-01 01:08:54.688     321.34

# %%
df2.isna().sum()
# Out:
# mag              0
# dmin         12263
# rms              2
# magType          1
# longitude        0
# latitude         0
# elevation        0
# dtype: int64

# %%
df2
# Out:
#                           mag     dmin   rms magType   longitude   latitude  \
# time
# 2020-01-01 00:01:56.590  2.75  0.75020  0.45      md  -67.127500  19.217500
# 2020-01-01 00:03:38.210  2.55  0.60950  0.16      md  -67.090100  19.076600
# 2020-01-01 00:10:43.850  3.08  0.88430  0.41      md  -67.836500  19.193300
# 2020-01-01 00:25:35.920  2.61  0.06275  0.17      ml -155.807167  19.627667
# 2020-01-01 00:28:20.289  5.10  1.19000  0.79      mb  152.551400  -5.324500
# ...                       ...      ...   ...     ...         ...        ...
# 2024-12-31 22:32:02.906  4.60  1.91500  0.61      mb  127.264000   8.012700
# 2024-12-31 22:45:49.069  4.30  1.31400  0.51      mb   40.000300   9.050000
# 2024-12-31 22:51:02.867  4.30  1.51300  0.53      mb   40.207400   8.790500
# 2024-12-31 23:13:20.048  5.00  0.47000  0.83     mwr  -70.623100 -20.182600
# 2024-12-31 23:28:55.746  4.30  3.63900  0.84      mb   40.012400   9.177200
#
#                          elevation
# time
# 2020-01-01 00:01:56.590      12.00
# 2020-01-01 00:03:38.210       6.00
# 2020-01-01 00:10:43.850      28.00
# 2020-01-01 00:25:35.920      12.86
# 2020-01-01 00:28:20.289      40.24
# ...                            ...
# 2024-12-31 22:32:02.906      10.00
# 2024-12-31 22:45:49.069      10.00
# 2024-12-31 22:51:02.867      10.00
# 2024-12-31 23:13:20.048      35.00
# 2024-12-31 23:28:55.746      10.00
#
# [139311 rows x 7 columns]

# %%
df_mean_fill = event_counts_for_diff_window2(df2, "mean")
df_no_mean_fill = event_counts_for_diff_window2(df2, "no_mean")

# %%
df_mean_fill.head(10)
# Out:
#                      time   mag     dmin   rms magType   longitude   latitude  \
# 0 2020-01-01 00:01:56.590  2.75  0.75020  0.45      md  -67.127500  19.217500
# 1 2020-01-01 00:03:38.210  2.55  0.60950  0.16      md  -67.090100  19.076600
# 2 2020-01-01 00:10:43.850  3.08  0.88430  0.41      md  -67.836500  19.193300
# 3 2020-01-01 00:25:35.920  2.61  0.06275  0.17      ml -155.807167  19.627667
# 4 2020-01-01 00:28:20.289  5.10  1.19000  0.79      mb  152.551400  -5.324500
# 5 2020-01-01 00:35:48.020  4.60  1.21800  1.08      mb  152.600300  -5.337300
# 6 2020-01-01 00:38:00.890  2.80  0.11580  0.23      md  -66.831100  17.869800
# 7 2020-01-01 00:57:01.290  2.67  0.96080  0.44      md  -67.210500  19.128500
# 8 2020-01-01 01:00:32.490  2.64  0.96880  0.21      md  -66.266800  18.693300
# 9 2020-01-01 01:08:54.688  4.50  1.47800  0.65      mb  138.330900  32.287900
#
#    elevation  time_since_last_event    time_bin lat_bin_mid lon_bin_mid  \
# 0      12.00            1133.090368  2020-01-01     17.5755    -68.4000
# 1       6.00             101.620000  2020-01-01     17.5755    -68.4000
# 2      28.00             425.640000  2020-01-01     17.5755    -68.4000
# 3      12.86             892.070000  2020-01-01     20.9810   -154.8000
# 4      40.24             164.369000  2020-01-01     -6.2625    154.7990
# 5      32.93             447.731000  2020-01-01     -6.2625    154.7990
# 6       7.00             132.870000  2020-01-01     17.5755    -68.4000
# 7       8.00            1140.400000  2020-01-01     17.5755    -68.4000
# 8      29.00             211.200000  2020-01-01     17.5755    -68.4000
# 9     321.34             502.198000  2020-01-01     31.1970    140.3995
#
#    lat_lon_bin_encoded  mag_count  mag_max  mag_mean  time_<lambda>
# 0                  456        135      5.4  3.416593      85688.273
# 1                  456        135      5.4  3.416593      85688.273
# 2                  456        135      5.4  3.416593      85688.273
# 3                  475        135      5.4  3.416593      85688.273
# 4                  416        135      5.4  3.416593      85688.273
# 5                  416        135      5.4  3.416593      85688.273
# 6                  456        135      5.4  3.416593      85688.273
# 7                  456        135      5.4  3.416593      85688.273
# 8                  456        135      5.4  3.416593      85688.273
# 9                  587        135      5.4  3.416593      85688.273

# %%
df_no_mean_fill.isna().sum()
# Out:
# time                     0
# mag                      0
# dmin                     0
# rms                      0
# magType                  1
# longitude                0
# latitude                 0
# elevation                0
# time_since_last_event    0
# time_bin                 0
# lat_bin_mid              0
# lon_bin_mid              0
# lat_lon_bin_encoded      0
# mag_count                0
# mag_max                  0
# mag_mean                 0
# time_<lambda>            0
# dtype: int64

# %%
pesudo_df3 = df_no_mean_fill.copy()
pesudo_df4 = pesudo_df3[pesudo_df3['dmin'] == 0]
pesudo_df4
# Out:
#                           time   mag  dmin   rms magType   longitude  \
# 36     2020-01-01 07:04:14.310  3.08   0.0  0.12      ml  -98.144667
# 37     2020-01-01 07:08:55.795  2.50   0.0  0.55      ml -157.284100
# 38     2020-01-01 07:25:42.342  2.90   0.0  0.48      ml -151.614000
# 53     2020-01-01 08:54:48.535  2.60   0.0  0.29      ml -153.560500
# 66     2020-01-01 10:11:35.413  2.70   0.0  0.49      ml -145.116900
# ...                        ...   ...   ...   ...     ...         ...
# 139221 2024-12-30 20:59:52.837  3.50   0.0  0.65      ml -152.182500
# 139223 2024-12-30 21:29:31.047  2.70   0.0  0.60      ml -152.901700
# 139241 2024-12-31 02:48:32.980  2.60   0.0  0.73      ml -137.279000
# 139257 2024-12-31 08:14:09.088  3.00   0.0  0.64      ml -158.915200
# 139270 2024-12-31 11:34:38.614  2.70   0.0  0.75      ml -156.641000
#
#         latitude  elevation  time_since_last_event    time_bin lat_bin_mid  \
# 36       36.4115        7.8                208.441  2020-01-01     38.0075
# 37       66.3300        4.7                281.485  2020-01-01     65.2510
# 38       59.9645       68.6               1006.547  2020-01-01     58.4400
# 53       59.3896      111.7                101.745  2020-01-01     58.4400
# 66       63.3218        4.6                300.223  2020-01-01     61.8455
# ...          ...        ...                    ...         ...         ...
# 139221   61.5947      115.8                664.858  2024-12-30     61.8455
# 139223   59.8064      107.6                512.660  2024-12-30     58.4400
# 139241   58.5725        8.5                903.657  2024-12-31     58.4400
# 139257   55.7220       60.1                456.878  2024-12-31     55.0345
# 139270   56.3511       40.6                 92.550  2024-12-31     55.0345
#
#        lon_bin_mid  lat_lon_bin_encoded  mag_count  mag_max  mag_mean  \
# 36           -97.2                  637        135      5.4  3.416593
# 37          -154.8                  887        135      5.4  3.416593
# 38          -154.8                  852        135      5.4  3.416593
# 53          -154.8                  852        135      5.4  3.416593
# 66          -147.6                  869        135      5.4  3.416593
# ...            ...                  ...        ...      ...       ...
# 139221      -154.8                  870         90      5.5  3.971333
# 139223      -154.8                  852         90      5.5  3.971333
# 139241      -140.4                  850         77      5.1  3.811169
# 139257      -162.0                  828         77      5.1  3.811169
# 139270      -154.8                  827         77      5.1  3.811169
#
#         time_<lambda>
# 36          85688.273
# 37          85688.273
# 38          85688.273
# 53          85688.273
# 66          85688.273
# ...               ...
# 139221      84455.143
# 139223      84455.143
# 139241      83526.957
# 139257      83526.957
# 139270      83526.957
#
# [13062 rows x 17 columns]

# %%
df_mean_fill.set_index('time', inplace=True)
df_mean_fill
# Out:
#                           mag     dmin   rms magType   longitude   latitude  \
# time
# 2020-01-01 00:01:56.590  2.75  0.75020  0.45      md  -67.127500  19.217500
# 2020-01-01 00:03:38.210  2.55  0.60950  0.16      md  -67.090100  19.076600
# 2020-01-01 00:10:43.850  3.08  0.88430  0.41      md  -67.836500  19.193300
# 2020-01-01 00:25:35.920  2.61  0.06275  0.17      ml -155.807167  19.627667
# 2020-01-01 00:28:20.289  5.10  1.19000  0.79      mb  152.551400  -5.324500
# ...                       ...      ...   ...     ...         ...        ...
# 2024-12-31 22:32:02.906  4.60  1.91500  0.61      mb  127.264000   8.012700
# 2024-12-31 22:45:49.069  4.30  1.31400  0.51      mb   40.000300   9.050000
# 2024-12-31 22:51:02.867  4.30  1.51300  0.53      mb   40.207400   8.790500
# 2024-12-31 23:13:20.048  5.00  0.47000  0.83     mwr  -70.623100 -20.182600
# 2024-12-31 23:28:55.746  4.30  3.63900  0.84      mb   40.012400   9.177200
#
#                          elevation  time_since_last_event    time_bin  \
# time
# 2020-01-01 00:01:56.590      12.00            1133.090368  2020-01-01
# 2020-01-01 00:03:38.210       6.00             101.620000  2020-01-01
# 2020-01-01 00:10:43.850      28.00             425.640000  2020-01-01
# 2020-01-01 00:25:35.920      12.86             892.070000  2020-01-01
# 2020-01-01 00:28:20.289      40.24             164.369000  2020-01-01
# ...                            ...                    ...         ...
# 2024-12-31 22:32:02.906      10.00            6000.538000  2024-12-31
# 2024-12-31 22:45:49.069      10.00             826.163000  2024-12-31
# 2024-12-31 22:51:02.867      10.00             313.798000  2024-12-31
# 2024-12-31 23:13:20.048      35.00            1337.181000  2024-12-31
# 2024-12-31 23:28:55.746      10.00             935.698000  2024-12-31
#
#                         lat_bin_mid lon_bin_mid  lat_lon_bin_encoded  \
# time
# 2020-01-01 00:01:56.590     17.5755     -68.400                  456
# 2020-01-01 00:03:38.210     17.5755     -68.400                  456
# 2020-01-01 00:10:43.850     17.5755     -68.400                  456
# 2020-01-01 00:25:35.920     20.9810    -154.800                  475
# 2020-01-01 00:28:20.289     -6.2625     154.799                  416
# ...                             ...         ...                  ...
# 2024-12-31 22:32:02.906      7.3595     126.000                  810
# 2024-12-31 22:45:49.069      7.3595      39.600                  814
# 2024-12-31 22:51:02.867      7.3595      39.600                  814
# 2024-12-31 23:13:20.048    -19.8840     -68.400                  111
# 2024-12-31 23:28:55.746     10.7645      39.600                  998
#
#                          mag_count  mag_max  mag_mean  time_<lambda>
# time
# 2020-01-01 00:01:56.590        135      5.4  3.416593      85688.273
# 2020-01-01 00:03:38.210        135      5.4  3.416593      85688.273
# 2020-01-01 00:10:43.850        135      5.4  3.416593      85688.273
# 2020-01-01 00:25:35.920        135      5.4  3.416593      85688.273
# 2020-01-01 00:28:20.289        135      5.4  3.416593      85688.273
# ...                            ...      ...       ...            ...
# 2024-12-31 22:32:02.906         77      5.1  3.811169      83526.957
# 2024-12-31 22:45:49.069         77      5.1  3.811169      83526.957
# 2024-12-31 22:51:02.867         77      5.1  3.811169      83526.957
# 2024-12-31 23:13:20.048         77      5.1  3.811169      83526.957
# 2024-12-31 23:28:55.746         77      5.1  3.811169      83526.957
#
# [139311 rows x 16 columns]

# %%
df_no_mean_fill.set_index('time', inplace=True)
df_no_mean_fill
# Out:
#                           mag     dmin   rms magType   longitude   latitude  \
# time
# 2020-01-01 00:01:56.590  2.75  0.75020  0.45      md  -67.127500  19.217500
# 2020-01-01 00:03:38.210  2.55  0.60950  0.16      md  -67.090100  19.076600
# 2020-01-01 00:10:43.850  3.08  0.88430  0.41      md  -67.836500  19.193300
# 2020-01-01 00:25:35.920  2.61  0.06275  0.17      ml -155.807167  19.627667
# 2020-01-01 00:28:20.289  5.10  1.19000  0.79      mb  152.551400  -5.324500
# ...                       ...      ...   ...     ...         ...        ...
# 2024-12-31 22:32:02.906  4.60  1.91500  0.61      mb  127.264000   8.012700
# 2024-12-31 22:45:49.069  4.30  1.31400  0.51      mb   40.000300   9.050000
# 2024-12-31 22:51:02.867  4.30  1.51300  0.53      mb   40.207400   8.790500
# 2024-12-31 23:13:20.048  5.00  0.47000  0.83     mwr  -70.623100 -20.182600
# 2024-12-31 23:28:55.746  4.30  3.63900  0.84      mb   40.012400   9.177200
#
#                          elevation  time_since_last_event    time_bin  \
# time
# 2020-01-01 00:01:56.590      12.00                  0.000  2020-01-01
# 2020-01-01 00:03:38.210       6.00                101.620  2020-01-01
# 2020-01-01 00:10:43.850      28.00                425.640  2020-01-01
# 2020-01-01 00:25:35.920      12.86                892.070  2020-01-01
# 2020-01-01 00:28:20.289      40.24                164.369  2020-01-01
# ...                            ...                    ...         ...
# 2024-12-31 22:32:02.906      10.00               6000.538  2024-12-31
# 2024-12-31 22:45:49.069      10.00                826.163  2024-12-31
# 2024-12-31 22:51:02.867      10.00                313.798  2024-12-31
# 2024-12-31 23:13:20.048      35.00               1337.181  2024-12-31
# 2024-12-31 23:28:55.746      10.00                935.698  2024-12-31
#
#                         lat_bin_mid lon_bin_mid  lat_lon_bin_encoded  \
# time
# 2020-01-01 00:01:56.590     17.5755     -68.400                  456
# 2020-01-01 00:03:38.210     17.5755     -68.400                  456
# 2020-01-01 00:10:43.850     17.5755     -68.400                  456
# 2020-01-01 00:25:35.920     20.9810    -154.800                  475
# 2020-01-01 00:28:20.289     -6.2625     154.799                  416
# ...                             ...         ...                  ...
# 2024-12-31 22:32:02.906      7.3595     126.000                  810
# 2024-12-31 22:45:49.069      7.3595      39.600                  814
# 2024-12-31 22:51:02.867      7.3595      39.600                  814
# 2024-12-31 23:13:20.048    -19.8840     -68.400                  111
# 2024-12-31 23:28:55.746     10.7645      39.600                  998
#
#                          mag_count  mag_max  mag_mean  time_<lambda>
# time
# 2020-01-01 00:01:56.590        135      5.4  3.416593      85688.273
# 2020-01-01 00:03:38.210        135      5.4  3.416593      85688.273
# 2020-01-01 00:10:43.850        135      5.4  3.416593      85688.273
# 2020-01-01 00:25:35.920        135      5.4  3.416593      85688.273
# 2020-01-01 00:28:20.289        135      5.4  3.416593      85688.273
# ...                            ...      ...       ...            ...
# 2024-12-31 22:32:02.906         77      5.1  3.811169      83526.957
# 2024-12-31 22:45:49.069         77      5.1  3.811169      83526.957
# 2024-12-31 22:51:02.867         77      5.1  3.811169      83526.957
# 2024-12-31 23:13:20.048         77      5.1  3.811169      83526.957
# 2024-12-31 23:28:55.746         77      5.1  3.811169      83526.957
#
# [139311 rows x 16 columns]

# %%
# Encoding the data
df_no_mean_fill = imput_encode(df_no_mean_fill)
df_mean_fill = imput_encode(df_mean_fill)

# %%
df_mean_fill
# Out:
#                           mag     dmin   rms  magType   longitude   latitude  \
# time
# 2020-01-01 00:01:56.590  2.75  0.75020  0.45        2  -67.127500  19.217500
# 2020-01-01 00:03:38.210  2.55  0.60950  0.16        2  -67.090100  19.076600
# 2020-01-01 00:10:43.850  3.08  0.88430  0.41        2  -67.836500  19.193300
# 2020-01-01 00:25:35.920  2.61  0.06275  0.17        4 -155.807167  19.627667
# 2020-01-01 00:28:20.289  5.10  1.19000  0.79        0  152.551400  -5.324500
# ...                       ...      ...   ...      ...         ...        ...
# 2024-12-31 22:32:02.906  4.60  1.91500  0.61        0  127.264000   8.012700
# 2024-12-31 22:45:49.069  4.30  1.31400  0.51        0   40.000300   9.050000
# 2024-12-31 22:51:02.867  4.30  1.51300  0.53        0   40.207400   8.790500
# 2024-12-31 23:13:20.048  5.00  0.47000  0.83       13  -70.623100 -20.182600
# 2024-12-31 23:28:55.746  4.30  3.63900  0.84        0   40.012400   9.177200
#
#                          elevation  time_since_last_event    time_bin  \
# time
# 2020-01-01 00:01:56.590      12.00            1133.090368  2020-01-01
# 2020-01-01 00:03:38.210       6.00             101.620000  2020-01-01
# 2020-01-01 00:10:43.850      28.00             425.640000  2020-01-01
# 2020-01-01 00:25:35.920      12.86             892.070000  2020-01-01
# 2020-01-01 00:28:20.289      40.24             164.369000  2020-01-01
# ...                            ...                    ...         ...
# 2024-12-31 22:32:02.906      10.00            6000.538000  2024-12-31
# 2024-12-31 22:45:49.069      10.00             826.163000  2024-12-31
# 2024-12-31 22:51:02.867      10.00             313.798000  2024-12-31
# 2024-12-31 23:13:20.048      35.00            1337.181000  2024-12-31
# 2024-12-31 23:28:55.746      10.00             935.698000  2024-12-31
#
#                         lat_bin_mid lon_bin_mid  lat_lon_bin_encoded  \
# time
# 2020-01-01 00:01:56.590     17.5755     -68.400                  456
# 2020-01-01 00:03:38.210     17.5755     -68.400                  456
# 2020-01-01 00:10:43.850     17.5755     -68.400                  456
# 2020-01-01 00:25:35.920     20.9810    -154.800                  475
# 2020-01-01 00:28:20.289     -6.2625     154.799                  416
# ...                             ...         ...                  ...
# 2024-12-31 22:32:02.906      7.3595     126.000                  810
# 2024-12-31 22:45:49.069      7.3595      39.600                  814
# 2024-12-31 22:51:02.867      7.3595      39.600                  814
# 2024-12-31 23:13:20.048    -19.8840     -68.400                  111
# 2024-12-31 23:28:55.746     10.7645      39.600                  998
#
#                          mag_count  mag_max  mag_mean  time_<lambda>
# time
# 2020-01-01 00:01:56.590        135      5.4  3.416593      85688.273
# 2020-01-01 00:03:38.210        135      5.4  3.416593      85688.273
# 2020-01-01 00:10:43.850        135      5.4  3.416593      85688.273
# 2020-01-01 00:25:35.920        135      5.4  3.416593      85688.273
# 2020-01-01 00:28:20.289        135      5.4  3.416593      85688.273
# ...                            ...      ...       ...            ...
# 2024-12-31 22:32:02.906         77      5.1  3.811169      83526.957
# 2024-12-31 22:45:49.069         77      5.1  3.811169      83526.957
# 2024-12-31 22:51:02.867         77      5.1  3.811169      83526.957
# 2024-12-31 23:13:20.048         77      5.1  3.811169      83526.957
# 2024-12-31 23:28:55.746         77      5.1  3.811169      83526.957
#
# [139311 rows x 16 columns]

# %%
nm_train_dataloader, nm_valid_dataloader, nm_test_dataloader, nm_scaler_X, nm_scaler_Y = DataLoader_Conversion(df_no_mean_fill)
m_train_dataloader, m_valid_dataloader, m_test_dataloader, m_scaler_X, m_scaler_Y = DataLoader_Conversion(df_mean_fill)
# Out:
# Splitting dataset for the first time...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10572\853830710.py in ?()
# ----> 1 nm_train_dataloader, nm_valid_dataloader, nm_test_dataloader, nm_scaler_X, nm_scaler_Y = DataLoader_Conversion(df_no_mean_fill)
#       2 m_train_dataloader, m_valid_dataloader, m_test_dataloader, m_scaler_X, m_scaler_Y = DataLoader_Conversion(df_mean_fill)
#
# c:\Projs\COde\Earthquake\eq_prediction\src\training\training_nn.py in ?(data, test_data)
#     241
#     242     Returns:
#     243         tuple: train_dataloader, valid_dataloader, (test_dataloader), scaler_X, scaler_Y
#     244     """
# --> 245     cached_splits = split_data(data)
#     246     X_train, y_train, X_val, y_val, X_test, y_test, scaler_X, scaler_Y = cached_splits
#     247
#     248     # Create DataLoader objects
#
# c:\Projs\COde\Earthquake\eq_prediction\src\training\training_nn.py in ?(data)
#     208         X1 = VarTar(data)[0]
#     209         Y1 = VarTar(data)[1]
#     210
#     211         # Scale the features and targets
# --> 212         scaled_X, scaler_X, scaled_Y, scaler_Y = scale_data(X1, Y1)
#     213
#     214         # Creating the Single Step Multi Variable Seperate Sampler
#     215         X, Y = SingleStepMultiVARS_SeperateSampler(scaled_X, scaled_Y, window_size, target_column)
#
# c:\Projs\COde\Earthquake\eq_prediction\src\training\training_nn.py in ?(X1, Y1)
#     180     from concurrent.futures import ThreadPoolExecutor
#     181
#     182     with ThreadPoolExecutor() as executor:
#     183         futures = [executor.submit(scaler_dataset, X1), executor.submit(scaler_dataset, Y1)]
# --> 184         results = [future.result() for future in futures]
#     185
#     186     scaled_X, scaler_X = results[0]
#     187     scaled_Y, scaler_Y = results[1]
#
# c:\Projs\COde\Earthquake\eq_prediction\src\training\training_nn.py in ?(.0)
# --> 184 def scale_data(X1: pd.DataFrame, Y1: pd.DataFrame) -> tuple:
#     185     """
#     186     Scales the input features (X1) and targets (Y1) using the scaler_dataset function from data_preprocessing.py.
#     187
#
# ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py in ?(self, timeout)
#     446                 else:
#     447                     raise TimeoutError()
#     448         finally:
#     449             # Break a reference cycle with the exception in self._exception
# --> 450             self = None
#
# ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\_base.py in ?(self)
#     389             try:
#     390                 raise self._exception
#     391             finally:
#     392                 # Break a reference cycle with the exception in self._exception
# --> 393                 self = None
#     394         else:
#     395             return self._result
#
# ~\AppData\Local\Programs\Python\Python310\lib\concurrent\futures\thread.py in ?(self)
#      52             result = self.fn(*self.args, **self.kwargs)
#      53         except BaseException as exc:
#      54             self.future.set_exception(exc)
#      55             # Break a reference cycle with the exception 'exc'
# ---> 56             self = None
#      57         else:
#      58             self.future.set_result(result)
#
# c:\Projs\COde\Earthquake\eq_prediction\src\preprocessing\data_preprocessing.py in ?(dataSet)
#      97         pd.DataFrame: Scaled and normalized DataFrame.
#      98     """
#      99     scale = MinMaxScaler(feature_range=(0,1))
#     100
# --> 101     scaled_dataset = scale.fit_transform(dataSet)
#     102     scaled_dataset = pd.DataFrame(scaled_dataset, columns=dataSet.columns, index=dataSet.index)
#     103     return scaled_dataset, scale
#
# c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     311     @wraps(f)
#     312     def wrapped(self, X, *args, **kwargs):
# --> 313         data_to_wrap = f(self, X, *args, **kwargs)
#     314         if isinstance(data_to_wrap, tuple):
#     315             # only wrap the first output for cross decomposition
#     316             return_tuple = (
#
# c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# -> 1098             return self.fit(X, **fit_params).transform(X)
#    1099         else:
#    1100             # fit method of arity 2 (supervised transformation)
#    1101             return self.fit(X, y, **fit_params).transform(X)
#
# c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y)
#     446             Fitted scaler.
#     447         """
#     448         # Reset internal state before fitting
#     449         self._reset()
# --> 450         return self.partial_fit(X, y)
#
# c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y)
#     486
#     487         xp, _ = get_namespace(X)
#     488
#     489         first_pass = not hasattr(self, "n_samples_seen_")
# --> 490         X = self._validate_data(
#     491             X,
#     492             reset=first_pass,
#     493             dtype=_array_api.supported_float_dtypes(xp),
#
# c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     747         # Use NumPy API to support order
#     748         if copy is True:
#     749             array = numpy.array(array, order=order, dtype=dtype)
#     750         else:
# --> 751             array = numpy.asarray(array, order=order, dtype=dtype)
#     752
#     753         # At this point array is a NumPy ndarray. We convert it to an array
#     754         # container that is consistent with the input's namespace.
#
# c:\Projs\COde\Earthquake\eq_prediction\earthquakevenv\lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# TypeError: float() argument must be a string or a real number, not 'Period'

# %%
|
