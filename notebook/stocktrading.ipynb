# %%
import yfinance
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import yfinance
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd

def fetch_stock_data(tickers, days_back=30):
    """
    Fetch stock data for given tickers for a specified number of days.
    
    Parameters:
    tickers (list): List of stock ticker symbols (e.g., ['AAPL', 'GOOGL'])
    days_back (int): Number of days of historical data to fetch
    
    Returns:
    dict: Dictionary containing DataFrames with stock data for each ticker
    """
    # Calculate date range
    end_date = datetime.now()
    start_date = end_date - timedelta(days=days_back)
    
    stock_data = {}
    
    for ticker in tickers:
        try:
            # Create ticker object
            stock = yf.Ticker(ticker)
            
            # Fetch historical data
            hist_data = stock.history(start=start_date, end=end_date)
            
            # Get additional stock info
            info = stock.info
            
            # Add important info to the DataFrame
            hist_data['Symbol'] = ticker
            hist_data['Company_Name'] = info.get('longName', '')
            hist_data['Industry'] = info.get('industry', '')
            hist_data['Sector'] = info.get('sector', '')
            hist_data['Market_Cap'] = info.get('marketCap', '')
            
            # Calculate daily returns
            hist_data['Daily_Return'] = hist_data['Close'].pct_change()
            
            # Format the data
            hist_data = hist_data.round(2)
            
            stock_data[ticker] = hist_data
            
        except Exception as e:
            print(f"Error fetching data for {ticker}: {str(e)}")
    
    return stock_data

def get_latest_prices(stock_data):
    """
    Extract the most recent closing prices and details for each stock.
    
    Parameters:
    stock_data (dict): Dictionary of stock DataFrames from fetch_stock_data
    
    Returns:
    pandas.DataFrame: Latest closing prices and details for each stock
    """
    latest_data = []
    
    for ticker, data in stock_data.items():
        if not data.empty:
            latest = data.iloc[-1]
            latest_data.append({
                'Symbol': ticker,
                'Company_Name': latest['Company_Name'],
                'Close': latest['Close'],
                'Volume': latest['Volume'],
                'Daily_Return': latest['Daily_Return'],
                'Industry': latest['Industry'],
                'Sector': latest['Sector'],
                'Market_Cap': latest['Market_Cap']
            })
    
    return pd.DataFrame(latest_data)

# %%
# Example usage
tickers = ['ABCAPITAL.NS', 'IEX', 'ZOMATO.NS']  # Add your desired stock symbols

# Fetch the data
stock_data = fetch_stock_data(tickers)

# Get latest prices and details
latest_prices = get_latest_prices(stock_data)
print(latest_prices)

# To see detailed historical data for a specific stock
# print(stock_data['AAPL'])
# Out:
#          Symbol                  Company_Name   Close    Volume  Daily_Return  \
# 0  ABCAPITAL.NS  Aditya Birla Capital Limited  183.24   1541103         -0.01
# 1           IEX              IDEX Corporation  211.11    166100         -0.01
# 2     ZOMATO.NS                Zomato Limited  271.25  18997843         -0.01
#
#                          Industry              Sector     Market_Cap
# 0         Financial Conglomerates  Financial Services   477616930816
# 1  Specialty Industrial Machinery         Industrials    15985944576
# 2                 Internet Retail   Consumer Cyclical  2588403302400

# %%
stock_data
# Out:
# {'ABCAPITAL.NS':                              Open    High     Low   Close   Volume  Dividends  \
#  Date
#  2024-11-28 00:00:00+05:30  194.30  196.17  193.05  193.81  2342790        0.0
#  2024-11-29 00:00:00+05:30  195.00  196.30  192.68  194.33  2754013        0.0
#  2024-12-02 00:00:00+05:30  195.20  195.30  191.91  194.18  2093046        0.0
00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-11-29 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-02 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-03 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-04 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-05 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-06 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-09 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-10 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-11 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-12 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-13 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-16 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-17 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-18 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-19 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-20 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-23 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-24 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-26 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#  2024-12-27 00:00:00+05:30        0.0           0.0  ZOMATO.NS  Zomato Limited
#
#                                    Industry             Sector     Market_Cap  \
#  Date
#  2024-11-28 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-11-29 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-02 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-03 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-04 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-05 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-06 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-09 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-10 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-11 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-12 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-13 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-16 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-17 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-18 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-19 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-20 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-23 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-24 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-26 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#  2024-12-27 00:00:00+05:30  Internet Retail  Consumer Cyclical  2588403302400
#
#                             Daily_Return
#  Date
#  2024-11-28 00:00:00+05:30           NaN
#  2024-11-29 00:00:00+05:30         -0.02
#  2024-12-02 00:00:00+05:30          0.01
#  2024-12-03 00:00:00+05:30         -0.01
#  2024-12-04 00:00:00+05:30          0.02
#  2024-12-05 00:00:00+05:30          0.05
#  2024-12-06 00:00:00+05:30          0.01
#  2024-12-09 00:00:00+05:30         -0.03
#  2024-12-10 00:00:00+05:30          0.00
#  2024-12-11 00:00:00+05:30         -0.01
#  2024-12-12 00:00:00+05:30         -0.02
#  2024-12-13 00:00:00+05:30          0.01
#  2024-12-16 00:00:00+05:30          0.02
#  2024-12-17 00:00:00+05:30          0.01
#  2024-12-18 00:00:00+05:30         -0.02
#  2024-12-19 00:00:00+05:30         -0.01
#  2024-12-20 00:00:00+05:30         -0.02
#  2024-12-23 00:00:00+05:30         -0.03
#  2024-12-24 00:00:00+05:30          0.00
#  2024-12-26 00:00:00+05:30         -0.01
#  2024-12-27 00:00:00+05:30         -0.01  }

# %% [markdown]
# ---
#
# # New Build

# %%
import tensorflow as tf
import keras
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Check TensorFlow version
print("TensorFlow Version: ", tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 import keras
#       3 import yfinance as yf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ------------
# alembic                            1.13.3
# aniso8601                          9.0.1
# annotated-types                    0.7.0
# anyio                              4.6.0
# asttokens                          2.4.1
# attrs                              24.2.0
# beautifulsoup4                     4.12.3
# blinker                            1.8.2
# bs4                                0.0.2
# cachetools                         5.5.0
# certifi                            2024.7.4
# charset-normalizer                 3.3.2
# click                              8.1.7
# cloudpickle                        3.0.0
# colorama                           0.4.6
# comet-ml                           3.45.0
# comm                               0.2.2
# configobj                          5.0.8
# contourpy                          1.2.1
# cycler                             0.12.1
# databricks-sdk                     0.33.0
# debugpy                            1.8.2
# decorator                          5.1.1
# Deprecated                         1.2.14
# docker                             7.1.0
# dulwich                            0.22.1
# everett                            3.1.0
# exceptiongroup                     1.2.2
# executing                          2.0.1
# fastapi                            0.115.0
# filelock                           3.13.1
# Flask                              3.0.3
# fonttools                          4.53.1
# frozendict                         2.4.6
# fsspec                             2024.2.0
# geojson                            3.1.0
# geopandas                          1.0.1
# gitdb                              4.0.11
# GitPython                          3.1.43
# google-auth                        2.35.0
# graphene                           3.3
# graphql-core                       3.2.4
# graphql-relay                      3.2.0
# greenlet                           3.1.1
# h11                                0.14.0
# html5lib                           1.1
# idna                               3.7
# importlib_metadata                 8.4.0
# ipykernel                          6.29.5
# ipython                            8.26.0
# itsdangerous                       2.2.0
# jedi                               0.19.1
# Jinja2                             3.1.3
# joblib                             1.4.2
# jsonschema                         4.23.0
# jsonschema-specifications          2023.12.1
# jupyter_client                     8.6.2
# jupyter_core                       5.7.2
# kiwisolver                         1.4.5
# lxml                               5.3.0
# Mako                               1.3.5
# Markdown                           3.7
# markdown-it-py                     3.0.0
# MarkupSafe                         2.1.5
# matplotlib                         3.9.1
# matplotlib-inline                  0.1.7
# mdurl                              0.1.2
# mlflow                             2.16.2
# mlflow-skinny                      2.16.2
# mpmath                             1.3.0
# multitasking                       0.0.11
# nest-asyncio                       1.6.0
# networkx                           3.2.1
# numpy                              1.25.2
# opentelemetry-api                  1.27.0
# opentelemetry-sdk                  1.27.0
# opentelemetry-semantic-conventions 0.48b0
# packaging                          24.1
# pandas                             2.2.2
# parso                              0.8.4
# patsy                              0.5.6
# peewee                             3.17.8
# pillow                             10.4.0
# pip                                24.2
# platformdirs                       4.2.2
# prompt_toolkit                     3.0.47
# protobuf                           5.28.2
# psutil                             6.0.0
# pure_eval                          0.2.3
# pyarrow                            17.0.0
# pyasn1                             0.6.1
# pyasn1_modules                     0.4.1
# pydantic                           2.9.2
# pydantic_core                      2.23.4
# Pygments                           2.18.0
# pyogrio                            0.9.0
# pyparsing                          3.1.2
# pyproj                             3.6.1
# python-box                         6.1.0
# python-dateutil                    2.9.0.post0
# python-dotenv                      1.0.1
# pytz                               2024.1
# pywin32                            306
# PyYAML                             6.0.2
# pyzmq                              26.0.3
# referencing                        0.35.1
# requests                           2.32.3
# requests-toolbelt                  1.0.0
# rich                               13.8.1
# rpds-py                            0.20.0
# rsa                                4.9
# scikit-learn                       1.5.1
# scipy                              1.14.0
# seaborn                            0.13.2
# semantic-version                   2.10.0
# sentry-sdk                         2.14.0
# setuptools                         57.4.0
# shapely                            2.0.5
# simplejson                         3.19.3
# six                                1.16.0
# smmap                              5.0.1
# sniffio                            1.3.1
# soupsieve                          2.6
# SQLAlchemy                         2.0.35
# sqlparse                           0.5.1
# stack-data                         0.6.3
# starlette                          0.38.6
# statsmodels                        0.14.2
# sympy                              1.12
# threadpoolctl                      3.5.0
# torch                              2.4.0+cu124
# torchaudio                         2.4.0+cu124
# torchvision                        0.19.0+cu124
# tornado                            6.4.1
# tqdm                               4.66.5
# traitlets                          5.14.3
# typing_extensions                  4.9.0
# tzdata                             2024.1
# urllib3                            2.2.2
# uvicorn                            0.30.6
# waitress                           3.0.0
# wcwidth                            0.2.13
# webencodings                       0.5.1
# Werkzeug                           3.0.4
# wrapt                              1.16.0
# wurlitzer                          3.1.1
# xgboost                            2.1.1
# xgboost-cpu                        2.1.1
# yfinance                           0.2.51
# zipp                               3.20.2

# %%
# !pip show tensorflow
# Out:
# WARNING: Package(s) not found: tensorflow
